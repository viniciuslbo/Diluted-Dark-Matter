# %% [markdown]
# #Import

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib import rc
from matplotlib.pyplot import gca,show
from IPython.display import Math, display
import numpy as np
import scipy as sp
import sympy as sym
from scipy.integrate import odeint, solve_ivp, ode, quad, quadrature
from scipy.interpolate import interp1d
from scipy.special import kv,zeta, polygamma, factorial
from matplotlib.offsetbox import AnchoredText
import time
import scipy.ndimage as ndimage
from matplotlib.offsetbox import AnchoredText
import matplotlib.cm as cm
import scipy.integrate as integrate
import mpmath as mp
from mpmath import *
import math

# %% [markdown]
# # Define $g_e$ and $g_s$

# %%
def gs(y):
    if (((0)<= y) and ( y<=(1.99526e-05))):
          return  (3.9139) + ( y-(0))*((3.9139)-(3.9139))/((1.99526e-05)-(0)) 
 
    if (((1.99526e-05)<= y) and ( y<=(2.23872e-05))):
          return  (3.9139) + ( y-(1.99526e-05))*((3.9139)-(3.9139))/((2.23872e-05)-(1.99526e-05)) 
 
    if (((2.23872e-05)<= y) and ( y<=(2.51189e-05))):
          return  (3.9139) + ( y-(2.23872e-05))*((3.9139)-(3.9139))/((2.51189e-05)-(2.23872e-05)) 
 
    if (((2.51189e-05)<= y) and ( y<=(2.81838e-05))):
          return  (3.9139) + ( y-(2.51189e-05))*((3.91393)-(3.9139))/((2.81838e-05)-(2.51189e-05)) 
 
    if (((2.81838e-05)<= y) and ( y<=(3.16228e-05))):
          return  (3.91393) + ( y-(2.81838e-05))*((3.91406)-(3.91393))/((3.16228e-05)-(2.81838e-05)) 
 
    if (((3.16228e-05)<= y) and ( y<=(3.54813e-05))):
          return  (3.91406) + ( y-(3.16228e-05))*((3.9146)-(3.91406))/((3.54813e-05)-(3.16228e-05)) 
 
    if (((3.54813e-05)<= y) and ( y<=(3.98107e-05))):
          return  (3.9146) + ( y-(3.54813e-05))*((3.91647)-(3.9146))/((3.98107e-05)-(3.54813e-05)) 
 
    if (((3.98107e-05)<= y) and ( y<=(4.46684e-05))):
          return  (3.91647) + ( y-(3.98107e-05))*((3.92191)-(3.91647))/((4.46684e-05)-(3.98107e-05)) 
 
    if (((4.46684e-05)<= y) and ( y<=(5.01187e-05))):
          return  (3.92191) + ( y-(4.46684e-05))*((3.93549)-(3.92191))/((5.01187e-05)-(4.46684e-05)) 
 
    if (((5.01187e-05)<= y) and ( y<=(5.62341e-05))):
          return  (3.93549) + ( y-(5.01187e-05))*((3.96501)-(3.93549))/((5.62341e-05)-(5.01187e-05)) 
 
    if (((5.62341e-05)<= y) and ( y<=(6.30958e-05))):
          return  (3.96501) + ( y-(5.62341e-05))*((4.02175)-(3.96501))/((6.30958e-05)-(5.62341e-05)) 
 
    if (((6.30958e-05)<= y) and ( y<=(7.07946e-05))):
          return  (4.02175) + ( y-(6.30958e-05))*((4.11956)-(4.02175))/((7.07946e-05)-(6.30958e-05)) 
 
    if (((7.07946e-05)<= y) and ( y<=(7.94328e-05))):
          return  (4.11956) + ( y-(7.07946e-05))*((4.27256)-(4.11956))/((7.94328e-05)-(7.07946e-05)) 
 
    if (((7.94328e-05)<= y) and ( y<=(8.91251e-05))):
          return  (4.27256) + ( y-(7.94328e-05))*((4.49209)-(4.27256))/((8.91251e-05)-(7.94328e-05)) 
 
    if (((8.91251e-05)<= y) and ( y<=(0.0001))):
          return  (4.49209) + ( y-(8.91251e-05))*((4.78386)-(4.49209))/((0.0001)-(8.91251e-05)) 
 
    if (((0.0001)<= y) and ( y<=(0.000112202))):
          return  (4.78386) + ( y-(0.0001))*((5.14616)-(4.78386))/((0.000112202)-(0.0001)) 
 
    if (((0.000112202)<= y) and ( y<=(0.000125892))):
          return  (5.14616) + ( y-(0.000112202))*((5.56975)-(5.14616))/((0.000125892)-(0.000112202)) 
 
    if (((0.000125892)<= y) and ( y<=(0.000141254))):
          return  (5.56975) + ( y-(0.000125892))*((6.03927)-(5.56975))/((0.000141254)-(0.000125892)) 
 
    if (((0.000141254)<= y) and ( y<=(0.000158489))):
          return  (6.03927) + ( y-(0.000141254))*((6.53574)-(6.03927))/((0.000158489)-(0.000141254)) 
 
    if (((0.000158489)<= y) and ( y<=(0.000177828))):
          return  (6.53574) + ( y-(0.000158489))*((7.03931)-(6.53574))/((0.000177828)-(0.000158489)) 
 
    if (((0.000177828)<= y) and ( y<=(0.000199526))):
          return  (7.03931) + ( y-(0.000177828))*((7.53167)-(7.03931))/((0.000199526)-(0.000177828)) 
 
    if (((0.000199526)<= y) and ( y<=(0.000223872))):
          return  (7.53167) + ( y-(0.000199526))*((7.99779)-(7.53167))/((0.000223872)-(0.000199526)) 
 
    if (((0.000223872)<= y) and ( y<=(0.000251189))):
          return  (7.99779) + ( y-(0.000223872))*((8.42675)-(7.99779))/((0.000251189)-(0.000223872)) 
 
    if (((0.000251189)<= y) and ( y<=(0.000281838))):
          return  (8.42675) + ( y-(0.000251189))*((8.81184)-(8.42675))/((0.000281838)-(0.000251189)) 
 
    if (((0.000281838)<= y) and ( y<=(0.000316228))):
          return  (8.81184) + ( y-(0.000281838))*((9.15015)-(8.81184))/((0.000316228)-(0.000281838)) 
 
    if (((0.000316228)<= y) and ( y<=(0.000354813))):
          return  (9.15015) + ( y-(0.000316228))*((9.44183)-(9.15015))/((0.000354813)-(0.000316228)) 
 
    if (((0.000354813)<= y) and ( y<=(0.000398107))):
          return  (9.44183) + ( y-(0.000354813))*((9.68926)-(9.44183))/((0.000398107)-(0.000354813)) 
 
    if (((0.000398107)<= y) and ( y<=(0.000446684))):
          return  (9.68926) + ( y-(0.000398107))*((9.89622)-(9.68926))/((0.000446684)-(0.000398107)) 
 
    if (((0.000446684)<= y) and ( y<=(0.000501187))):
          return  (9.89622) + ( y-(0.000446684))*((10.0673)-(9.89622))/((0.000501187)-(0.000446684)) 
 
    if (((0.000501187)<= y) and ( y<=(0.000562341))):
          return  (10.0673) + ( y-(0.000501187))*((10.2072)-(10.0673))/((0.000562341)-(0.000501187)) 
 
    if (((0.000562341)<= y) and ( y<=(0.000630957))):
          return  (10.2072) + ( y-(0.000562341))*((10.3208)-(10.2072))/((0.000630957)-(0.000562341)) 
 
    if (((0.000630957)<= y) and ( y<=(0.000707946))):
          return  (10.3208) + ( y-(0.000630957))*((10.4122)-(10.3208))/((0.000707946)-(0.000630957)) 
 
    if (((0.000707946)<= y) and ( y<=(0.000794328))):
          return  (10.4122) + ( y-(0.000707946))*((10.4854)-(10.4122))/((0.000794328)-(0.000707946)) 
 
    if (((0.000794328)<= y) and ( y<=(0.000891251))):
          return  (10.4854) + ( y-(0.000794328))*((10.5437)-(10.4854))/((0.000891251)-(0.000794328)) 
 
    if (((0.000891251)<= y) and ( y<=(0.001))):
          return  (10.5437) + ( y-(0.000891251))*((10.59)-(10.5437))/((0.001)-(0.000891251)) 
 
    if (((0.001)<= y) and ( y<=(0.00112202))):
          return  (10.59) + ( y-(0.001))*((10.6267)-(10.59))/((0.00112202)-(0.001)) 
 
    if (((0.00112202)<= y) and ( y<=(0.00125892))):
          return  (10.6267) + ( y-(0.00112202))*((10.6556)-(10.6267))/((0.00125892)-(0.00112202)) 
 
    if (((0.00125892)<= y) and ( y<=(0.00141254))):
          return  (10.6556) + ( y-(0.00125892))*((10.6785)-(10.6556))/((0.00141254)-(0.00125892)) 
 
    if (((0.00141254)<= y) and ( y<=(0.00158489))):
          return  (10.6785) + ( y-(0.00141254))*((10.6965)-(10.6785))/((0.00158489)-(0.00141254)) 
 
    if (((0.00158489)<= y) and ( y<=(0.00177828))):
          return  (10.6965) + ( y-(0.00158489))*((10.7106)-(10.6965))/((0.00177828)-(0.00158489)) 
 
    if (((0.00177828)<= y) and ( y<=(0.00199526))):
          return  (10.7106) + ( y-(0.00177828))*((10.7218)-(10.7106))/((0.00199526)-(0.00177828)) 
 
    if (((0.00199526)<= y) and ( y<=(0.00223872))):
          return  (10.7218) + ( y-(0.00199526))*((10.7284)-(10.7218))/((0.00223872)-(0.00199526)) 
 
    if (((0.00223872)<= y) and ( y<=(0.00251189))):
          return  (10.7284) + ( y-(0.00223872))*((10.7337)-(10.7284))/((0.00251189)-(0.00223872)) 
 
    if (((0.00251189)<= y) and ( y<=(0.00281838))):
          return  (10.7337) + ( y-(0.00251189))*((10.7378)-(10.7337))/((0.00281838)-(0.00251189)) 
 
    if (((0.00281838)<= y) and ( y<=(0.00316228))):
          return  (10.7378) + ( y-(0.00281838))*((10.741)-(10.7378))/((0.00316228)-(0.00281838)) 
 
    if (((0.00316228)<= y) and ( y<=(0.00354813))):
          return  (10.741) + ( y-(0.00316228))*((10.7435)-(10.741))/((0.00354813)-(0.00316228)) 
 
    if (((0.00354813)<= y) and ( y<=(0.00398107))):
          return  (10.7435) + ( y-(0.00354813))*((10.7448)-(10.7435))/((0.00398107)-(0.00354813)) 
 
    if (((0.00398107)<= y) and ( y<=(0.00446684))):
          return  (10.7448) + ( y-(0.00398107))*((10.7459)-(10.7448))/((0.00446684)-(0.00398107)) 
 
    if (((0.00446684)<= y) and ( y<=(0.00501187))):
          return  (10.7459) + ( y-(0.00446684))*((10.7468)-(10.7459))/((0.00501187)-(0.00446684)) 
 
    if (((0.00501187)<= y) and ( y<=(0.00562341))):
          return  (10.7468) + ( y-(0.00501187))*((10.7475)-(10.7468))/((0.00562341)-(0.00501187)) 
 
    if (((0.00562341)<= y) and ( y<=(0.00630957))):
          return  (10.7475) + ( y-(0.00562341))*((10.748)-(10.7475))/((0.00630957)-(0.00562341)) 
 
    if (((0.00630957)<= y) and ( y<=(0.00707946))):
          return  (10.748) + ( y-(0.00630957))*((10.7486)-(10.748))/((0.00707946)-(0.00630957)) 
 
    if (((0.00707946)<= y) and ( y<=(0.00794328))):
          return  (10.7486) + ( y-(0.00707946))*((10.7497)-(10.7486))/((0.00794328)-(0.00707946)) 
 
    if (((0.00794328)<= y) and ( y<=(0.00891251))):
          return  (10.7497) + ( y-(0.00794328))*((10.7522)-(10.7497))/((0.00891251)-(0.00794328)) 
 
    if (((0.00891251)<= y) and ( y<=(0.01))):
          return  (10.7522) + ( y-(0.00891251))*((10.7584)-(10.7522))/((0.01)-(0.00891251)) 
 
    if (((0.01)<= y) and ( y<=(0.0112202))):
          return  (10.7584) + ( y-(0.01))*((10.7722)-(10.7584))/((0.0112202)-(0.01)) 
 
    if (((0.0112202)<= y) and ( y<=(0.0125892))):
          return  (10.7722) + ( y-(0.0112202))*((10.8003)-(10.7722))/((0.0125892)-(0.0112202)) 
 
    if (((0.0125892)<= y) and ( y<=(0.0141254))):
          return  (10.8003) + ( y-(0.0125892))*((10.8516)-(10.8003))/((0.0141254)-(0.0125892)) 
 
    if (((0.0141254)<= y) and ( y<=(0.0158489))):
          return  (10.8516) + ( y-(0.0141254))*((10.9371)-(10.8516))/((0.0158489)-(0.0141254)) 
 
    if (((0.0158489)<= y) and ( y<=(0.0177828))):
          return  (10.9371) + ( y-(0.0158489))*((11.0677)-(10.9371))/((0.0177828)-(0.0158489)) 
 
    if (((0.0177828)<= y) and ( y<=(0.0199526))):
          return  (11.0677) + ( y-(0.0177828))*((11.2528)-(11.0677))/((0.0199526)-(0.0177828)) 
 
    if (((0.0199526)<= y) and ( y<=(0.0223872))):
          return  (11.2528) + ( y-(0.0199526))*((11.4977)-(11.2528))/((0.0223872)-(0.0199526)) 
 
    if (((0.0223872)<= y) and ( y<=(0.0251189))):
          return  (11.4977) + ( y-(0.0223872))*((11.8023)-(11.4977))/((0.0251189)-(0.0223872)) 
 
    if (((0.0251189)<= y) and ( y<=(0.0281838))):
          return  (11.8023) + ( y-(0.0251189))*((12.1611)-(11.8023))/((0.0281838)-(0.0251189)) 
 
    if (((0.0281838)<= y) and ( y<=(0.0316228))):
          return  (12.1611) + ( y-(0.0281838))*((12.5633)-(12.1611))/((0.0316228)-(0.0281838)) 
 
    if (((0.0316228)<= y) and ( y<=(0.0354813))):
          return  (12.5633) + ( y-(0.0316228))*((12.9952)-(12.5633))/((0.0354813)-(0.0316228)) 
 
    if (((0.0354813)<= y) and ( y<=(0.0398107))):
          return  (12.9952) + ( y-(0.0354813))*((13.4414)-(12.9952))/((0.0398107)-(0.0354813)) 
 
    if (((0.0398107)<= y) and ( y<=(0.0421697))):
          return  (13.4414) + ( y-(0.0398107))*((13.6653)-(13.4414))/((0.0421697)-(0.0398107)) 
 
    if (((0.0421697)<= y) and ( y<=(0.0446684))):
          return  (13.6653) + ( y-(0.0421697))*((13.8877)-(13.6653))/((0.0446684)-(0.0421697)) 
 
    if (((0.0446684)<= y) and ( y<=(0.0473151))):
          return  (13.8877) + ( y-(0.0446684))*((14.1071)-(13.8877))/((0.0473151)-(0.0446684)) 
 
    if (((0.0473151)<= y) and ( y<=(0.0501187))):
          return  (14.1071) + ( y-(0.0473151))*((14.3227)-(14.1071))/((0.0501187)-(0.0473151)) 
 
    if (((0.0501187)<= y) and ( y<=(0.0530885))):
          return  (14.3227) + ( y-(0.0501187))*((14.5337)-(14.3227))/((0.0530885)-(0.0501187)) 
 
    if (((0.0530885)<= y) and ( y<=(0.0562341))):
          return  (14.5337) + ( y-(0.0530885))*((14.7398)-(14.5337))/((0.0562341)-(0.0530885)) 
 
    if (((0.0562341)<= y) and ( y<=(0.0595662))):
          return  (14.7398) + ( y-(0.0562341))*((14.9411)-(14.7398))/((0.0595662)-(0.0562341)) 
 
    if (((0.0595662)<= y) and ( y<=(0.0630957))):
          return  (14.9411) + ( y-(0.0595662))*((15.1382)-(14.9411))/((0.0630957)-(0.0595662)) 
 
    if (((0.0630957)<= y) and ( y<=(0.0668344))):
          return  (15.1382) + ( y-(0.0630957))*((15.3325)-(15.1382))/((0.0668344)-(0.0630957)) 
 
    if (((0.0668344)<= y) and ( y<=(0.0707946))):
          return  (15.3325) + ( y-(0.0668344))*((15.5256)-(15.3325))/((0.0707946)-(0.0668344)) 
 
    if (((0.0707946)<= y) and ( y<=(0.0749894))):
          return  (15.5256) + ( y-(0.0707946))*((15.7202)-(15.5256))/((0.0749894)-(0.0707946)) 
 
    if (((0.0749894)<= y) and ( y<=(0.0794328))):
          return  (15.7202) + ( y-(0.0749894))*((15.9197)-(15.7202))/((0.0794328)-(0.0749894)) 
 
    if (((0.0794328)<= y) and ( y<=(0.0841395))):
          return  (15.9197) + ( y-(0.0794328))*((16.1288)-(15.9197))/((0.0841395)-(0.0794328)) 
 
    if (((0.0841395)<= y) and ( y<=(0.0891251))):
          return  (16.1288) + ( y-(0.0841395))*((16.3533)-(16.1288))/((0.0891251)-(0.0841395)) 
 
    if (((0.0891251)<= y) and ( y<=(0.0944061))):
          return  (16.3533) + ( y-(0.0891251))*((16.6007)-(16.3533))/((0.0944061)-(0.0891251)) 
 
    if (((0.0944061)<= y) and ( y<=(0.1))):
          return  (16.6007) + ( y-(0.0944061))*((16.8804)-(16.6007))/((0.1)-(0.0944061)) 
 
    if (((0.1)<= y) and ( y<=(0.105925))):
          return  (16.8804) + ( y-(0.1))*((17.4133)-(16.8804))/((0.105925)-(0.1)) 
 
    if (((0.105925)<= y) and ( y<=(0.112202))):
          return  (17.4133) + ( y-(0.105925))*((18.1043)-(17.4133))/((0.112202)-(0.105925)) 
 
    if (((0.112202)<= y) and ( y<=(0.11885))):
          return  (18.1043) + ( y-(0.112202))*((18.9927)-(18.1043))/((0.11885)-(0.112202)) 
 
    if (((0.11885)<= y) and ( y<=(0.125892))):
          return  (18.9927) + ( y-(0.11885))*((20.1266)-(18.9927))/((0.125892)-(0.11885)) 
 
    if (((0.125892)<= y) and ( y<=(0.133352))):
          return  (20.1266) + ( y-(0.125892))*((21.5643)-(20.1266))/((0.133352)-(0.125892)) 
 
    if (((0.133352)<= y) and ( y<=(0.141254))):
          return  (21.5643) + ( y-(0.133352))*((23.3772)-(21.5643))/((0.141254)-(0.133352)) 
 
    if (((0.141254)<= y) and ( y<=(0.149624))):
          return  (23.3772) + ( y-(0.141254))*((25.6518)-(23.3772))/((0.149624)-(0.141254)) 
 
    if (((0.149624)<= y) and ( y<=(0.158489))):
          return  (25.6518) + ( y-(0.149624))*((28.4929)-(25.6518))/((0.158489)-(0.149624)) 
 
    if (((0.158489)<= y) and ( y<=(0.167881))):
          return  (28.4929) + ( y-(0.158489))*((31.2248)-(28.4929))/((0.167881)-(0.158489)) 
 
    if (((0.167881)<= y) and ( y<=(0.177828))):
          return  (31.2248) + ( y-(0.167881))*((33.9567)-(31.2248))/((0.177828)-(0.167881)) 
 
    if (((0.177828)<= y) and ( y<=(0.188365))):
          return  (33.9567) + ( y-(0.177828))*((36.6886)-(33.9567))/((0.188365)-(0.177828)) 
 
    if (((0.188365)<= y) and ( y<=(0.199526))):
          return  (36.6886) + ( y-(0.188365))*((39.4205)-(36.6886))/((0.199526)-(0.188365)) 
 
    if (((0.199526)<= y) and ( y<=(0.211349))):
          return  (39.4205) + ( y-(0.199526))*((42.1524)-(39.4205))/((0.211349)-(0.199526)) 
 
    if (((0.211349)<= y) and ( y<=(0.223872))):
          return  (42.1524) + ( y-(0.211349))*((44.8843)-(42.1524))/((0.223872)-(0.211349)) 
 
    if (((0.223872)<= y) and ( y<=(0.237138))):
          return  (44.8843) + ( y-(0.223872))*((47.5072)-(44.8843))/((0.237138)-(0.223872)) 
 
    if (((0.237138)<= y) and ( y<=(0.251189))):
          return  (47.5072) + ( y-(0.237138))*((49.9196)-(47.5072))/((0.251189)-(0.237138)) 
 
    if (((0.251189)<= y) and ( y<=(0.266072))):
          return  (49.9196) + ( y-(0.251189))*((52.1329)-(49.9196))/((0.266072)-(0.251189)) 
 
    if (((0.266072)<= y) and ( y<=(0.281838))):
          return  (52.1329) + ( y-(0.266072))*((54.1586)-(52.1329))/((0.281838)-(0.266072)) 
 
    if (((0.281838)<= y) and ( y<=(0.298538))):
          return  (54.1586) + ( y-(0.281838))*((56.0078)-(54.1586))/((0.298538)-(0.281838)) 
 
    if (((0.298538)<= y) and ( y<=(0.316228))):
          return  (56.0078) + ( y-(0.298538))*((57.692)-(56.0078))/((0.316228)-(0.298538)) 
 
    if (((0.316228)<= y) and ( y<=(0.334966))):
          return  (57.692) + ( y-(0.316228))*((59.2225)-(57.692))/((0.334966)-(0.316228)) 
 
    if (((0.334966)<= y) and ( y<=(0.354814))):
          return  (59.2225) + ( y-(0.334966))*((60.6106)-(59.2225))/((0.354814)-(0.334966)) 
 
    if (((0.354814)<= y) and ( y<=(0.375837))):
          return  (60.6106) + ( y-(0.354814))*((61.8676)-(60.6106))/((0.375837)-(0.354814)) 
 
    if (((0.375837)<= y) and ( y<=(0.398107))):
          return  (61.8676) + ( y-(0.375837))*((63.005)-(61.8676))/((0.398107)-(0.375837)) 
 
    if (((0.398107)<= y) and ( y<=(0.421696))):
          return  (63.005) + ( y-(0.398107))*((64.034)-(63.005))/((0.421696)-(0.398107)) 
 
    if (((0.421696)<= y) and ( y<=(0.446684))):
          return  (64.034) + ( y-(0.421696))*((64.966)-(64.034))/((0.446684)-(0.421696)) 
 
    if (((0.446684)<= y) and ( y<=(0.473152))):
          return  (64.966) + ( y-(0.446684))*((65.8123)-(64.966))/((0.473152)-(0.446684)) 
 
    if (((0.473152)<= y) and ( y<=(0.501187))):
          return  (65.8123) + ( y-(0.473152))*((66.5843)-(65.8123))/((0.501187)-(0.473152)) 
 
    if (((0.501187)<= y) and ( y<=(0.530885))):
          return  (66.5843) + ( y-(0.501187))*((67.3228)-(66.5843))/((0.530885)-(0.501187)) 
 
    if (((0.530885)<= y) and ( y<=(0.562341))):
          return  (67.3228) + ( y-(0.530885))*((68.0614)-(67.3228))/((0.562341)-(0.530885)) 
 
    if (((0.562341)<= y) and ( y<=(0.595662))):
          return  (68.0614) + ( y-(0.562341))*((68.8)-(68.0614))/((0.595662)-(0.562341)) 
 
    if (((0.595662)<= y) and ( y<=(0.630958))):
          return  (68.8) + ( y-(0.595662))*((69.5385)-(68.8))/((0.630958)-(0.595662)) 
 
    if (((0.630958)<= y) and ( y<=(0.668344))):
          return  (69.5385) + ( y-(0.630958))*((70.2771)-(69.5385))/((0.668344)-(0.630958)) 
 
    if (((0.668344)<= y) and ( y<=(0.707946))):
          return  (70.2771) + ( y-(0.668344))*((71.0157)-(70.2771))/((0.707946)-(0.668344)) 
 
    if (((0.707946)<= y) and ( y<=(0.749894))):
          return  (71.0157) + ( y-(0.707946))*((71.7542)-(71.0157))/((0.749894)-(0.707946)) 
 
    if (((0.749894)<= y) and ( y<=(0.794328))):
          return  (71.7542) + ( y-(0.749894))*((72.4928)-(71.7542))/((0.794328)-(0.749894)) 
 
    if (((0.794328)<= y) and ( y<=(0.841395))):
          return  (72.4928) + ( y-(0.794328))*((73.1335)-(72.4928))/((0.841395)-(0.794328)) 
 
    if (((0.841395)<= y) and ( y<=(0.891251))):
          return  (73.1335) + ( y-(0.841395))*((73.7743)-(73.1335))/((0.891251)-(0.841395)) 
 
    if (((0.891251)<= y) and ( y<=(0.944062))):
          return  (73.7743) + ( y-(0.891251))*((74.415)-(73.7743))/((0.944062)-(0.891251)) 
 
    if (((0.944062)<= y) and ( y<=(1))):
          return  (74.415) + ( y-(0.944062))*((75.0558)-(74.415))/((1)-(0.944062)) 
 
    if (((1)<= y) and ( y<=(1.05925))):
          return  (75.0558) + ( y-(1))*((75.6966)-(75.0558))/((1.05925)-(1)) 
 
    if (((1.05925)<= y) and ( y<=(1.12202))):
          return  (75.6966) + ( y-(1.05925))*((76.3373)-(75.6966))/((1.12202)-(1.05925)) 
 
    if (((1.12202)<= y) and ( y<=(1.1885))):
          return  (76.3373) + ( y-(1.12202))*((76.978)-(76.3373))/((1.1885)-(1.12202)) 
 
    if (((1.1885)<= y) and ( y<=(1.25893))):
          return  (76.978) + ( y-(1.1885))*((77.6188)-(76.978))/((1.25893)-(1.1885)) 
 
    if (((1.25893)<= y) and ( y<=(1.33352))):
          return  (77.6188) + ( y-(1.25893))*((78.1433)-(77.6188))/((1.33352)-(1.25893)) 
 
    if (((1.33352)<= y) and ( y<=(1.41254))):
          return  (78.1433) + ( y-(1.33352))*((78.6552)-(78.1433))/((1.41254)-(1.33352)) 
 
    if (((1.41254)<= y) and ( y<=(1.49624))):
          return  (78.6552) + ( y-(1.41254))*((79.1517)-(78.6552))/((1.49624)-(1.41254)) 
 
    if (((1.49624)<= y) and ( y<=(1.58489))):
          return  (79.1517) + ( y-(1.49624))*((79.6305)-(79.1517))/((1.58489)-(1.49624)) 
 
    if (((1.58489)<= y) and ( y<=(1.67881))):
          return  (79.6305) + ( y-(1.58489))*((80.1165)-(79.6305))/((1.67881)-(1.58489)) 
 
    if (((1.67881)<= y) and ( y<=(1.77828))):
          return  (80.1165) + ( y-(1.67881))*((80.5838)-(80.1165))/((1.77828)-(1.67881)) 
 
    if (((1.77828)<= y) and ( y<=(1.88365))):
          return  (80.5838) + ( y-(1.77828))*((81.0306)-(80.5838))/((1.88365)-(1.77828)) 
 
    if (((1.88365)<= y) and ( y<=(1.99526))):
          return  (81.0306) + ( y-(1.88365))*((81.4557)-(81.0306))/((1.99526)-(1.88365)) 
 
    if (((1.99526)<= y) and ( y<=(2.11349))):
          return  (81.4557) + ( y-(1.99526))*((81.8579)-(81.4557))/((2.11349)-(1.99526)) 
 
    if (((2.11349)<= y) and ( y<=(2.23872))):
          return  (81.8579) + ( y-(2.11349))*((82.2369)-(81.8579))/((2.23872)-(2.11349)) 
 
    if (((2.23872)<= y) and ( y<=(2.37138))):
          return  (82.2369) + ( y-(2.23872))*((82.5921)-(82.2369))/((2.37138)-(2.23872)) 
 
    if (((2.37138)<= y) and ( y<=(2.51189))):
          return  (82.5921) + ( y-(2.37138))*((82.9237)-(82.5921))/((2.51189)-(2.37138)) 
 
    if (((2.51189)<= y) and ( y<=(2.81838))):
          return  (82.9237) + ( y-(2.51189))*((83.5174)-(82.9237))/((2.81838)-(2.51189)) 
 
    if (((2.81838)<= y) and ( y<=(3.16228))):
          return  (83.5174) + ( y-(2.81838))*((84.0226)-(83.5174))/((3.16228)-(2.81838)) 
 
    if (((3.16228)<= y) and ( y<=(3.54814))):
          return  (84.0226) + ( y-(3.16228))*((84.4468)-(84.0226))/((3.54814)-(3.16228)) 
 
    if (((3.54814)<= y) and ( y<=(3.98107))):
          return  (84.4468) + ( y-(3.54814))*((84.7988)-(84.4468))/((3.98107)-(3.54814)) 
 
    if (((3.98107)<= y) and ( y<=(4.46684))):
          return  (84.7988) + ( y-(3.98107))*((85.0879)-(84.7988))/((4.46684)-(3.98107)) 
 
    if (((4.46684)<= y) and ( y<=(5.01187))):
          return  (85.0879) + ( y-(4.46684))*((85.3234)-(85.0879))/((5.01187)-(4.46684)) 
 
    if (((5.01187)<= y) and ( y<=(5.62341))):
          return  (85.3234) + ( y-(5.01187))*((85.514)-(85.3234))/((5.62341)-(5.01187)) 
 
    if (((5.62341)<= y) and ( y<=(6.30958))):
          return  (85.514) + ( y-(5.62341))*((85.6685)-(85.514))/((6.30958)-(5.62341)) 
 
    if (((6.30958)<= y) and ( y<=(7.07946))):
          return  (85.6685) + ( y-(6.30958))*((85.7962)-(85.6685))/((7.07946)-(6.30958)) 
 
    if (((7.07946)<= y) and ( y<=(7.94329))):
          return  (85.7962) + ( y-(7.07946))*((85.9087)-(85.7962))/((7.94329)-(7.07946)) 
 
    if (((7.94329)<= y) and ( y<=(8.91251))):
          return  (85.9087) + ( y-(7.94329))*((86.0221)-(85.9087))/((8.91251)-(7.94329)) 
 
    if (((8.91251)<= y) and ( y<=(10))):
          return  (86.0221) + ( y-(8.91251))*((86.1594)-(86.0221))/((10)-(8.91251)) 
 
    if (((10)<= y) and ( y<=(10.5925))):
          return  (86.1594) + ( y-(10))*((86.2463)-(86.1594))/((10.5925)-(10)) 
 
    if (((10.5925)<= y) and ( y<=(11.2202))):
          return  (86.2463) + ( y-(10.5925))*((86.3512)-(86.2463))/((11.2202)-(10.5925)) 
 
    if (((11.2202)<= y) and ( y<=(11.885))):
          return  (86.3512) + ( y-(11.2202))*((86.4789)-(86.3512))/((11.885)-(11.2202)) 
 
    if (((11.885)<= y) and ( y<=(12.5892))):
          return  (86.4789) + ( y-(11.885))*((86.6343)-(86.4789))/((12.5892)-(11.885)) 
 
    if (((12.5892)<= y) and ( y<=(13.3352))):
          return  (86.6343) + ( y-(12.5892))*((86.8221)-(86.6343))/((13.3352)-(12.5892)) 
 
    if (((13.3352)<= y) and ( y<=(14.1254))):
          return  (86.8221) + ( y-(13.3352))*((87.0469)-(86.8221))/((14.1254)-(13.3352)) 
 
    if (((14.1254)<= y) and ( y<=(14.9624))):
          return  (87.0469) + ( y-(14.1254))*((87.3125)-(87.0469))/((14.9624)-(14.1254)) 
 
    if (((14.9624)<= y) and ( y<=(15.8489))):
          return  (87.3125) + ( y-(14.9624))*((87.6221)-(87.3125))/((15.8489)-(14.9624)) 
 
    if (((15.8489)<= y) and ( y<=(16.788))):
          return  (87.6221) + ( y-(15.8489))*((87.9776)-(87.6221))/((16.788)-(15.8489)) 
 
    if (((16.788)<= y) and ( y<=(17.7828))):
          return  (87.9776) + ( y-(16.788))*((88.3801)-(87.9776))/((17.7828)-(16.788)) 
 
    if (((17.7828)<= y) and ( y<=(18.8365))):
          return  (88.3801) + ( y-(17.7828))*((88.8295)-(88.3801))/((18.8365)-(17.7828)) 
 
    if (((18.8365)<= y) and ( y<=(19.9526))):
          return  (88.8295) + ( y-(18.8365))*((89.3241)-(88.8295))/((19.9526)-(18.8365)) 
 
    if (((19.9526)<= y) and ( y<=(21.1349))):
          return  (89.3241) + ( y-(19.9526))*((89.8614)-(89.3241))/((21.1349)-(19.9526)) 
 
    if (((21.1349)<= y) and ( y<=(22.3872))):
          return  (89.8614) + ( y-(21.1349))*((90.4376)-(89.8614))/((22.3872)-(21.1349)) 
 
    if (((22.3872)<= y) and ( y<=(23.7137))):
          return  (90.4376) + ( y-(22.3872))*((91.0481)-(90.4376))/((23.7137)-(22.3872)) 
 
    if (((23.7137)<= y) and ( y<=(25.1189))):
          return  (91.0481) + ( y-(23.7137))*((91.6874)-(91.0481))/((25.1189)-(23.7137)) 
 
    if (((25.1189)<= y) and ( y<=(26.6073))):
          return  (91.6874) + ( y-(25.1189))*((92.3495)-(91.6874))/((26.6073)-(25.1189)) 
 
    if (((26.6073)<= y) and ( y<=(28.1838))):
          return  (92.3495) + ( y-(26.6073))*((93.0282)-(92.3495))/((28.1838)-(26.6073)) 
 
    if (((28.1838)<= y) and ( y<=(29.8539))):
          return  (93.0282) + ( y-(28.1838))*((93.7171)-(93.0282))/((29.8539)-(28.1838)) 
 
    if (((29.8539)<= y) and ( y<=(31.6228))):
          return  (93.7171) + ( y-(29.8539))*((94.4098)-(93.7171))/((31.6228)-(29.8539)) 
 
    if (((31.6228)<= y) and ( y<=(33.4965))):
          return  (94.4098) + ( y-(31.6228))*((95.1005)-(94.4098))/((33.4965)-(31.6228)) 
 
    if (((33.4965)<= y) and ( y<=(35.4813))):
          return  (95.1005) + ( y-(33.4965))*((95.7833)-(95.1005))/((35.4813)-(33.4965)) 
 
    if (((35.4813)<= y) and ( y<=(37.5837))):
          return  (95.7833) + ( y-(35.4813))*((96.4533)-(95.7833))/((37.5837)-(35.4813)) 
 
    if (((37.5837)<= y) and ( y<=(39.8107))):
          return  (96.4533) + ( y-(37.5837))*((97.106)-(96.4533))/((39.8107)-(37.5837)) 
 
    if (((39.8107)<= y) and ( y<=(42.1696))):
          return  (97.106) + ( y-(39.8107))*((97.7374)-(97.106))/((42.1696)-(39.8107)) 
 
    if (((42.1696)<= y) and ( y<=(44.6684))):
          return  (97.7374) + ( y-(42.1696))*((98.3444)-(97.7374))/((44.6684)-(42.1696)) 
 
    if (((44.6684)<= y) and ( y<=(47.3151))):
          return  (98.3444) + ( y-(44.6684))*((98.9244)-(98.3444))/((47.3151)-(44.6684)) 
 
    if (((47.3151)<= y) and ( y<=(50.1187))):
          return  (98.9244) + ( y-(47.3151))*((99.4756)-(98.9244))/((50.1187)-(47.3151)) 
 
    if (((50.1187)<= y) and ( y<=(53.0885))):
          return  (99.4756) + ( y-(50.1187))*((99.9967)-(99.4756))/((53.0885)-(50.1187)) 
 
    if (((53.0885)<= y) and ( y<=(56.2341))):
          return  (99.9967) + ( y-(53.0885))*((100.487)-(99.9967))/((56.2341)-(53.0885)) 
 
    if (((56.2341)<= y) and ( y<=(59.5664))):
          return  (100.487) + ( y-(56.2341))*((100.946)-(100.487))/((59.5664)-(56.2341)) 
 
    if (((59.5664)<= y) and ( y<=(63.0957))):
          return  (100.946) + ( y-(59.5664))*((101.374)-(100.946))/((63.0957)-(59.5664)) 
 
    if (((63.0957)<= y) and ( y<=(66.8344))):
          return  (101.374) + ( y-(63.0957))*((101.772)-(101.374))/((66.8344)-(63.0957)) 
 
    if (((66.8344)<= y) and ( y<=(70.7946))):
          return  (101.772) + ( y-(66.8344))*((102.14)-(101.772))/((70.7946)-(66.8344)) 
 
    if (((70.7946)<= y) and ( y<=(74.9894))):
          return  (102.14) + ( y-(70.7946))*((102.48)-(102.14))/((74.9894)-(70.7946)) 
 
    if (((74.9894)<= y) and ( y<=(79.4328))):
          return  (102.48) + ( y-(74.9894))*((102.792)-(102.48))/((79.4328)-(74.9894)) 
 
    if (((79.4328)<= y) and ( y<=(84.1395))):
          return  (102.792) + ( y-(79.4328))*((103.079)-(102.792))/((84.1395)-(79.4328)) 
 
    if (((84.1395)<= y) and ( y<=(89.1251))):
          return  (103.079) + ( y-(84.1395))*((103.341)-(103.079))/((89.1251)-(84.1395)) 
 
    if (((89.1251)<= y) and ( y<=(94.4061))):
          return  (103.341) + ( y-(89.1251))*((103.58)-(103.341))/((94.4061)-(89.1251)) 
 
    if (((94.4061)<= y) and ( y<=(100))):
          return  (103.58) + ( y-(94.4061))*((103.797)-(103.58))/((100)-(94.4061)) 
 
    if (((100)<= y) and ( y<=(105.925))):
          return  (103.797) + ( y-(100))*((103.995)-(103.797))/((105.925)-(100)) 
 
    if (((105.925)<= y) and ( y<=(112.202))):
          return  (103.995) + ( y-(105.925))*((104.174)-(103.995))/((112.202)-(105.925)) 
 
    if (((112.202)<= y) and ( y<=(118.85))):
          return  (104.174) + ( y-(112.202))*((104.335)-(104.174))/((118.85)-(112.202)) 
 
    if (((118.85)<= y) and ( y<=(125.892))):
          return  (104.335) + ( y-(118.85))*((104.482)-(104.335))/((125.892)-(118.85)) 
 
    if (((125.892)<= y) and ( y<=(133.352))):
          return  (104.482) + ( y-(125.892))*((104.614)-(104.482))/((133.352)-(125.892)) 
 
    if (((133.352)<= y) and ( y<=(141.254))):
          return  (104.614) + ( y-(133.352))*((104.733)-(104.614))/((141.254)-(133.352)) 
 
    if (((141.254)<= y) and ( y<=(149.624))):
          return  (104.733) + ( y-(141.254))*((104.84)-(104.733))/((149.624)-(141.254)) 
 
    if (((149.624)<= y) and ( y<=(158.489))):
          return  (104.84) + ( y-(149.624))*((104.936)-(104.84))/((158.489)-(149.624)) 
 
    if (((158.489)<= y) and ( y<=(167.88))):
          return  (104.936) + ( y-(158.489))*((105.022)-(104.936))/((167.88)-(158.489)) 
 
    if (((167.88)<= y) and ( y<=(177.828))):
          return  (105.022) + ( y-(167.88))*((105.1)-(105.022))/((177.828)-(167.88)) 
 
    if (((177.828)<= y) and ( y<=(188.366))):
          return  (105.1) + ( y-(177.828))*((105.169)-(105.1))/((188.366)-(177.828)) 
 
    if (((188.366)<= y) and ( y<=(199.526))):
          return  (105.169) + ( y-(188.366))*((105.231)-(105.169))/((199.526)-(188.366)) 
 
    if (((199.526)<= y) and ( y<=(211.349))):
          return  (105.231) + ( y-(199.526))*((105.287)-(105.231))/((211.349)-(199.526)) 
 
    if (((211.349)<= y) and ( y<=(223.873))):
          return  (105.287) + ( y-(211.349))*((105.337)-(105.287))/((223.873)-(211.349)) 
 
    if (((223.873)<= y) and ( y<=(237.137))):
          return  (105.337) + ( y-(223.873))*((105.382)-(105.337))/((237.137)-(223.873)) 
 
    if (((237.137)<= y) and ( y<=(251.189))):
          return  (105.382) + ( y-(237.137))*((105.421)-(105.382))/((251.189)-(237.137)) 
 
    if (((251.189)<= y) and ( y<=(266.072))):
          return  (105.421) + ( y-(251.189))*((105.457)-(105.421))/((266.072)-(251.189)) 
 
    if (((266.072)<= y) and ( y<=(281.838))):
          return  (105.457) + ( y-(266.072))*((105.489)-(105.457))/((281.838)-(266.072)) 
 
    if (((281.838)<= y) and ( y<=(298.538))):
          return  (105.489) + ( y-(281.838))*((105.517)-(105.489))/((298.538)-(281.838)) 
 
    if (((298.538)<= y) and ( y<=(316.228))):
          return  (105.517) + ( y-(298.538))*((105.542)-(105.517))/((316.228)-(298.538)) 
 
    if (((316.228)<= y) and ( y<=(334.966))):
          return  (105.542) + ( y-(316.228))*((105.565)-(105.542))/((334.966)-(316.228)) 
 
    if (((334.966)<= y) and ( y<=(354.813))):
          return  (105.565) + ( y-(334.966))*((105.585)-(105.565))/((354.813)-(334.966)) 
 
    if (((354.813)<= y) and ( y<=(375.839))):
          return  (105.585) + ( y-(354.813))*((105.603)-(105.585))/((375.839)-(354.813)) 
 
    if (((375.839)<= y) and ( y<=(398.107))):
          return  (105.603) + ( y-(375.839))*((105.619)-(105.603))/((398.107)-(375.839)) 
 
    if (((398.107)<= y) and ( y<=(421.697))):
          return  (105.619) + ( y-(398.107))*((105.633)-(105.619))/((421.697)-(398.107)) 
 
    if (((421.697)<= y) and ( y<=(446.685))):
          return  (105.633) + ( y-(421.697))*((105.646)-(105.633))/((446.685)-(421.697)) 
 
    if (((446.685)<= y) and ( y<=(473.152))):
          return  (105.646) + ( y-(446.685))*((105.657)-(105.646))/((473.152)-(446.685)) 
 
    if (((473.152)<= y) and ( y<=(501.187))):
          return  (105.657) + ( y-(473.152))*((105.667)-(105.657))/((501.187)-(473.152)) 
 
    if (((501.187)<= y) and ( y<=(530.884))):
          return  (105.667) + ( y-(501.187))*((105.676)-(105.667))/((530.884)-(501.187)) 
 
    if (((530.884)<= y) and ( y<=(562.341))):
          return  (105.676) + ( y-(530.884))*((105.684)-(105.676))/((562.341)-(530.884)) 
 
    if (((562.341)<= y) and ( y<=(595.662))):
          return  (105.684) + ( y-(562.341))*((105.691)-(105.684))/((595.662)-(562.341)) 
 
    if (((595.662)<= y) and ( y<=(630.957))):
          return  (105.691) + ( y-(595.662))*((105.698)-(105.691))/((630.957)-(595.662)) 
 
    if (((630.957)<= y) and ( y<=(668.344))):
          return  (105.698) + ( y-(630.957))*((105.704)-(105.698))/((668.344)-(630.957)) 
 
    if (((668.344)<= y) and ( y<=(707.946))):
          return  (105.704) + ( y-(668.344))*((105.709)-(105.704))/((707.946)-(668.344)) 
 
    if (((707.946)<= y) and ( y<=(749.894))):
          return  (105.709) + ( y-(707.946))*((105.713)-(105.709))/((749.894)-(707.946)) 
 
    if (((749.894)<= y) and ( y<=(794.328))):
          return  (105.713) + ( y-(749.894))*((105.717)-(105.713))/((794.328)-(749.894)) 
 
    if (((794.328)<= y) and ( y<=(841.397))):
          return  (105.717) + ( y-(794.328))*((105.721)-(105.717))/((841.397)-(794.328)) 
 
    if (((841.397)<= y) and ( y<=(891.253))):
          return  (105.721) + ( y-(841.397))*((105.724)-(105.721))/((891.253)-(841.397)) 
 
    if (((891.253)<= y) and ( y<=(944.061))):
          return  (105.724) + ( y-(891.253))*((105.727)-(105.724))/((944.061)-(891.253)) 
 
    if (((944.061)<= y) and ( y<=(1000))):
          return  (105.727) + ( y-(944.061))*((105.729)-(105.727))/((1000)-(944.061)) 
 
    if (((1000)<= y) and ( y<=(1059.25))):
          return  (105.729) + ( y-(1000))*((105.731)-(105.729))/((1059.25)-(1000)) 
 
    if (((1059.25)<= y) and ( y<=(1122.02))):
          return  (105.731) + ( y-(1059.25))*((105.734)-(105.731))/((1122.02)-(1059.25)) 
 
    if (((1122.02)<= y) and ( y<=(1188.5))):
          return  (105.734) + ( y-(1122.02))*((105.735)-(105.734))/((1188.5)-(1122.02)) 
 
    if (((1188.5)<= y) and ( y<=(1258.93))):
          return  (105.735) + ( y-(1188.5))*((105.737)-(105.735))/((1258.93)-(1188.5)) 
 
    if (((1258.93)<= y) and ( y<=(1333.52))):
          return  (105.737) + ( y-(1258.93))*((105.738)-(105.737))/((1333.52)-(1258.93)) 
 
    if (((1333.52)<= y) and ( y<=(1412.54))):
          return  (105.738) + ( y-(1333.52))*((105.74)-(105.738))/((1412.54)-(1333.52)) 
 
    if (((1412.54)<= y) and ( y<=(1496.23))):
          return  (105.74) + ( y-(1412.54))*((105.741)-(105.74))/((1496.23)-(1412.54)) 
 
    if (((1496.23)<= y) and ( y<=(1584.89))):
          return  (105.741) + ( y-(1496.23))*((105.742)-(105.741))/((1584.89)-(1496.23)) 
 
    if (((1584.89)<= y) and ( y<=(1678.81))):
          return  (105.742) + ( y-(1584.89))*((105.743)-(105.742))/((1678.81)-(1584.89)) 
 
    if (((1678.81)<= y) and ( y<=(1778.28))):
          return  (105.743) + ( y-(1678.81))*((105.743)-(105.743))/((1778.28)-(1678.81)) 
 
    if (((1778.28)<= y) and ( y<=(1883.65))):
          return  (105.743) + ( y-(1778.28))*((105.744)-(105.743))/((1883.65)-(1778.28)) 
 
    if (((1883.65)<= y) and ( y<=(1995.26))):
          return  (105.744) + ( y-(1883.65))*((105.745)-(105.744))/((1995.26)-(1883.65)) 
 
    if (((1995.26)<= y) and ( y<=(2113.49))):
          return  (105.745) + ( y-(1995.26))*((105.745)-(105.745))/((2113.49)-(1995.26)) 
 
    if (((2113.49)<= y) and ( y<=(2238.72))):
          return  (105.745) + ( y-(2113.49))*((105.746)-(105.745))/((2238.72)-(2113.49)) 
 
    if (((2238.72)<= y) and ( y<=(2371.37))):
          return  (105.746) + ( y-(2238.72))*((105.746)-(105.746))/((2371.37)-(2238.72)) 
 
    if (((2371.37)<= y) and ( y<=(2511.89))):
          return  (105.746) + ( y-(2371.37))*((105.747)-(105.746))/((2511.89)-(2371.37)) 
 
    if (((2511.89)<= y) and ( y<=(2660.72))):
          return  (105.747) + ( y-(2511.89))*((105.747)-(105.747))/((2660.72)-(2511.89)) 
 
    if (((2660.72)<= y) and ( y<=(2818.4))):
          return  (105.747) + ( y-(2660.72))*((105.747)-(105.747))/((2818.4)-(2660.72)) 
 
    if (((2818.4)<= y) and ( y<=(2985.38))):
          return  (105.747) + ( y-(2818.4))*((105.748)-(105.747))/((2985.38)-(2818.4)) 
 
    if (((2985.38)<= y) and ( y<=(3162.28))):
          return  (105.748) + ( y-(2985.38))*((105.748)-(105.748))/((3162.28)-(2985.38)) 
 
    if (((3162.28)<= y) and ( y<=(3349.66))):
          return  (105.748) + ( y-(3162.28))*((105.748)-(105.748))/((3349.66)-(3162.28)) 
 
    if (((3349.66)<= y) and ( y<=(3548.14))):
          return  (105.748) + ( y-(3349.66))*((105.748)-(105.748))/((3548.14)-(3349.66)) 
 
    if (((3548.14)<= y) and ( y<=(3758.38))):
          return  (105.748) + ( y-(3548.14))*((105.749)-(105.748))/((3758.38)-(3548.14)) 
 
    if (((3758.38)<= y) and ( y<=(3981.07))):
          return  (105.749) + ( y-(3758.38))*((105.749)-(105.749))/((3981.07)-(3758.38)) 
 
    if (((3981.07)<= y) and ( y<=(4216.97))):
          return  (105.749) + ( y-(3981.07))*((105.749)-(105.749))/((4216.97)-(3981.07)) 
 
    if (((4216.97)<= y) and ( y<=(4466.84))):
          return  (105.749) + ( y-(4216.97))*((105.749)-(105.749))/((4466.84)-(4216.97)) 
 
    if (((4466.84)<= y) and ( y<=(4731.51))):
          return  (105.749) + ( y-(4466.84))*((105.749)-(105.749))/((4731.51)-(4466.84)) 
 
    if (((4731.51)<= y) and ( y<=(5011.87))):
          return  (105.749) + ( y-(4731.51))*((105.749)-(105.749))/((5011.87)-(4731.51)) 
 
    if (((5011.87)<= y) and ( y<=(5308.84))):
          return  (105.749) + ( y-(5011.87))*((105.749)-(105.749))/((5308.84)-(5011.87)) 
 
    if (((5308.84)<= y) and ( y<=(5623.43))):
          return  (105.749) + ( y-(5308.84))*((105.749)-(105.749))/((5623.43)-(5308.84)) 
 
    if (((5623.43)<= y) and ( y<=(5956.64))):
          return  (105.749) + ( y-(5623.43))*((105.749)-(105.749))/((5956.64)-(5623.43)) 
 
    if (((5956.64)<= y) and ( y<=(6309.59))):
          return  (105.749) + ( y-(5956.64))*((105.749)-(105.749))/((6309.59)-(5956.64)) 
 
    if (((6309.59)<= y) and ( y<=(6683.45))):
          return  (105.749) + ( y-(6309.59))*((105.749)-(105.749))/((6683.45)-(6309.59)) 
 
    if (((6683.45)<= y) and ( y<=(7079.46))):
          return  (105.749) + ( y-(6683.45))*((105.75)-(105.749))/((7079.46)-(6683.45)) 
 
    if (((7079.46)<= y) and ( y<=(7498.94))):
          return  (105.75) + ( y-(7079.46))*((105.75)-(105.75))/((7498.94)-(7079.46)) 
 
    if (((7498.94)<= y) and ( y<=(7943.28))):
          return  (105.75) + ( y-(7498.94))*((105.75)-(105.75))/((7943.28)-(7498.94)) 
 
    if (((7943.28)<= y) and ( y<=(8413.95))):
          return  (105.75) + ( y-(7943.28))*((105.75)-(105.75))/((8413.95)-(7943.28)) 
 
    if (((8413.95)<= y) and ( y<=(8912.53))):
          return  (105.75) + ( y-(8413.95))*((105.75)-(105.75))/((8912.53)-(8413.95)) 
 
    if (((8912.53)<= y) and ( y<=(9440.61))):
          return  (105.75) + ( y-(8912.53))*((105.75)-(105.75))/((9440.61)-(8912.53)) 
 
    if (((9440.61)<= y) and ( y<=(10000))):
          return  (105.75) + ( y-(9440.61))*((105.75)-(105.75))/((10000)-(9440.61)) 
 
    if (((10000)<= y) and ( y<=(10592.6))):
          return  (105.75) + ( y-(10000))*((105.75)-(105.75))/((10592.6)-(10000)) 
 
    if (((10592.6)<= y) and ( y<=(11220.2))):
          return  (105.75) + ( y-(10592.6))*((105.75)-(105.75))/((11220.2)-(10592.6)) 
 
    if (((11220.2)<= y) and ( y<=(11885))):
          return  (105.75) + ( y-(11220.2))*((105.75)-(105.75))/((11885)-(11220.2)) 
 
    if (((11885)<= y) and ( y<=(12589.2))):
          return  (105.75) + ( y-(11885))*((105.75)-(105.75))/((12589.2)-(11885))
    else:
      return 105.75

# %%
def ge(x):
    if (((0)<=x) and (x<=(1.99526e-05))): 
        return (3.36722) + (x-(0))*((3.36722)-(3.36722))/((1.99526e-05)-(0))  
  
    if (((1.99526e-05)<=x) and (x<=(2.23872e-05))): 
        return (3.36722) + (x-(1.99526e-05))*((3.36722)-(3.36722))/((2.23872e-05)-(1.99526e-05))
  
    if (((2.23872e-05)<=x) and (x<=(2.51189e-05))): 
        return (3.36722) + (x-(2.23872e-05))*((3.36722)-(3.36722))/((2.51189e-05)-(2.23872e-05))  
  
    if (((2.51189e-05)<=x) and (x<=(2.81838e-05))): 
        return (3.36722) + (x-(2.51189e-05))*((3.36724)-(3.36722))/((2.81838e-05)-(2.51189e-05))  
  
    if (((2.81838e-05)<=x) and (x<=(3.16228e-05))): 
        return (3.36724) + (x-(2.81838e-05))*((3.36733)-(3.36724))/((3.16228e-05)-(2.81838e-05))  
  
    if (((3.16228e-05)<=x) and (x<=(3.54813e-05))): 
        return (3.36733) + (x-(3.16228e-05))*((3.36779)-(3.36733))/((3.54813e-05)-(3.16228e-05))  
  
    if (((3.54813e-05)<=x) and (x<=(3.98107e-05))): 
        return (3.36779) + (x-(3.54813e-05))*((3.36958)-(3.36779))/((3.98107e-05)-(3.54813e-05))  
  
    if (((3.98107e-05)<=x) and (x<=(4.46684e-05))): 
        return (3.36958) + (x-(3.98107e-05))*((3.37514)-(3.36958))/((4.46684e-05)-(3.98107e-05))  
  
    if (((4.46684e-05)<=x) and (x<=(5.01187e-05))): 
        return (3.37514) + (x-(4.46684e-05))*((3.38957)-(3.37514))/((5.01187e-05)-(4.46684e-05))  
  
    if (((5.01187e-05)<=x) and (x<=(5.62341e-05))): 
        return (3.38957) + (x-(5.01187e-05))*((3.42163)-(3.38957))/((5.62341e-05)-(5.01187e-05))  
  
    if (((5.62341e-05)<=x) and (x<=(6.30958e-05))): 
        return (3.42163) + (x-(5.62341e-05))*((3.48397)-(3.42163))/((6.30958e-05)-(5.62341e-05))  
  
    if (((6.30958e-05)<=x) and (x<=(7.07946e-05))): 
        return (3.48397) + (x-(6.30958e-05))*((3.59181)-(3.48397))/((7.07946e-05)-(6.30958e-05))  
  
    if (((7.07946e-05)<=x) and (x<=(7.94328e-05))): 
        return (3.59181) + (x-(7.07946e-05))*((3.76031)-(3.59181))/((7.94328e-05)-(7.07946e-05))  
  
    if (((7.94328e-05)<=x) and (x<=(8.91251e-05))): 
        return (3.76031) + (x-(7.94328e-05))*((4.00127)-(3.76031))/((8.91251e-05)-(7.94328e-05))  
  
    if (((8.91251e-05)<=x) and (x<=(0.0001))): 
        return (4.00127) + (x-(8.91251e-05))*((4.32033)-(4.00127))/((0.0001)-(8.91251e-05))  
  
    if (((0.0001)<=x) and (x<=(0.000112202))): 
        return (4.32033) + (x-(0.0001))*((4.71528)-(4.32033))/((0.000112202)-(0.0001))  
  
    if (((0.000112202)<=x) and (x<=(0.000125892))): 
        return (4.71528) + (x-(0.000112202))*((5.17614)-(4.71528))/((0.000125892)-(0.000112202))  
  
    if (((0.000125892)<=x) and (x<=(0.000141254))): 
        return (5.17614) + (x-(0.000125892))*((5.68652)-(5.17614))/((0.000141254)-(0.000125892))  
  
    if (((0.000141254)<=x) and (x<=(0.000158489))): 
        return (5.68652) + (x-(0.000141254))*((6.22601)-(5.68652))/((0.000158489)-(0.000141254))  
  
    if (((0.000158489)<=x) and (x<=(0.000177828))): 
        return (6.22601) + (x-(0.000158489))*((6.77307)-(6.22601))/((0.000177828)-(0.000158489))  
  
    if (((0.000177828)<=x) and (x<=(0.000199526))): 
        return (6.77307) + (x-(0.000177828))*((7.30768)-(6.77307))/((0.000199526)-(0.000177828))  
  
    if (((0.000199526)<=x) and (x<=(0.000223872))): 
        return (7.30768) + (x-(0.000199526))*((7.81325)-(7.30768))/((0.000223872)-(0.000199526))  
  
    if (((0.000223872)<=x) and (x<=(0.000251189))): 
        return (7.81325) + (x-(0.000223872))*((8.2777)-(7.81325))/((0.000251189)-(0.000223872))  
  
    if (((0.000251189)<=x) and (x<=(0.000281838))): 
        return (8.2777) + (x-(0.000251189))*((8.69362)-(8.2777))/((0.000281838)-(0.000251189))  
  
    if (((0.000281838)<=x) and (x<=(0.000316228))): 
        return (8.69362) + (x-(0.000281838))*((9.05787)-(8.69362))/((0.000316228)-(0.000281838))  
  
    if (((0.000316228)<=x) and (x<=(0.000354813))): 
        return (9.05787) + (x-(0.000316228))*((9.37078)-(9.05787))/((0.000354813)-(0.000316228))  
  
    if (((0.000354813)<=x) and (x<=(0.000398107))): 
        return (9.37078) + (x-(0.000354813))*((9.63515)-(9.37078))/((0.000398107)-(0.000354813))  
  
    if (((0.000398107)<=x) and (x<=(0.000446684))): 
        return (9.63515) + (x-(0.000398107))*((9.85539)-(9.63515))/((0.000446684)-(0.000398107))  
  
    if (((0.000446684)<=x) and (x<=(0.000501187))): 
        return (9.85539) + (x-(0.000446684))*((10.0367)-(9.85539))/((0.000501187)-(0.000446684))  
  
    if (((0.000501187)<=x) and (x<=(0.000562341))): 
        return (10.0367) + (x-(0.000501187))*((10.1844)-(10.0367))/((0.000562341)-(0.000501187))  
  
    if (((0.000562341)<=x) and (x<=(0.000630957))): 
        return (10.1844) + (x-(0.000562341))*((10.3038)-(10.1844))/((0.000630957)-(0.000562341))  
  
    if (((0.000630957)<=x) and (x<=(0.000707946))): 
        return (10.3038) + (x-(0.000630957))*((10.3997)-(10.3038))/((0.000707946)-(0.000630957))  
  
    if (((0.000707946)<=x) and (x<=(0.000794328))): 
        return (10.3997) + (x-(0.000707946))*((10.4763)-(10.3997))/((0.000794328)-(0.000707946))  
  
    if (((0.000794328)<=x) and (x<=(0.000891251))): 
        return (10.4763) + (x-(0.000794328))*((10.5372)-(10.4763))/((0.000891251)-(0.000794328))  
  
    if (((0.000891251)<=x) and (x<=(0.001))): 
        return (10.5372) + (x-(0.000891251))*((10.5855)-(10.5372))/((0.001)-(0.000891251))  
  
    if (((0.001)<=x) and (x<=(0.00112202))): 
        return (10.5855) + (x-(0.001))*((10.6237)-(10.5855))/((0.00112202)-(0.001))  
  
    if (((0.00112202)<=x) and (x<=(0.00125892))): 
        return (10.6237) + (x-(0.00112202))*((10.6539)-(10.6237))/((0.00125892)-(0.00112202))  
  
    if (((0.00125892)<=x) and (x<=(0.00141254))): 
        return (10.6539) + (x-(0.00125892))*((10.6778)-(10.6539))/((0.00141254)-(0.00125892))  
  
    if (((0.00141254)<=x) and (x<=(0.00158489))): 
        return (10.6778) + (x-(0.00141254))*((10.6966)-(10.6778))/((0.00158489)-(0.00141254))  
  
    if (((0.00158489)<=x) and (x<=(0.00177828))): 
        return (10.6966) + (x-(0.00158489))*((10.7114)-(10.6966))/((0.00177828)-(0.00158489))  
  
    if (((0.00177828)<=x) and (x<=(0.00199526))): 
        return (10.7114) + (x-(0.00177828))*((10.7238)-(10.7114))/((0.00199526)-(0.00177828))  
  
    if (((0.00199526)<=x) and (x<=(0.00223872))): 
        return (10.7238) + (x-(0.00199526))*((10.7294)-(10.7238))/((0.00223872)-(0.00199526))  
  
    if (((0.00223872)<=x) and (x<=(0.00251189))): 
        return (10.7294) + (x-(0.00223872))*((10.7345)-(10.7294))/((0.00251189)-(0.00223872))  
  
    if (((0.00251189)<=x) and (x<=(0.00281838))): 
        return (10.7345) + (x-(0.00251189))*((10.7386)-(10.7345))/((0.00281838)-(0.00251189))  
  
    if (((0.00281838)<=x) and (x<=(0.00316228))): 
        return (10.7386) + (x-(0.00281838))*((10.7418)-(10.7386))/((0.00316228)-(0.00281838))  
  
    if (((0.00316228)<=x) and (x<=(0.00354813))): 
        return (10.7418) + (x-(0.00316228))*((10.7444)-(10.7418))/((0.00354813)-(0.00316228))  
  
    if (((0.00354813)<=x) and (x<=(0.00398107))): 
        return (10.7444) + (x-(0.00354813))*((10.7453)-(10.7444))/((0.00398107)-(0.00354813))  
  
    if (((0.00398107)<=x) and (x<=(0.00446684))): 
        return (10.7453) + (x-(0.00398107))*((10.7462)-(10.7453))/((0.00446684)-(0.00398107))  
  
    if (((0.00446684)<=x) and (x<=(0.00501187))): 
        return (10.7462) + (x-(0.00446684))*((10.747)-(10.7462))/((0.00501187)-(0.00446684))  
  
    if (((0.00501187)<=x) and (x<=(0.00562341))): 
        return (10.747) + (x-(0.00501187))*((10.7476)-(10.747))/((0.00562341)-(0.00501187))  
  
    if (((0.00562341)<=x) and (x<=(0.00630957))): 
        return (10.7476) + (x-(0.00562341))*((10.7481)-(10.7476))/((0.00630957)-(0.00562341))  
  
    if (((0.00630957)<=x) and (x<=(0.00707946))): 
        return (10.7481) + (x-(0.00630957))*((10.7487)-(10.7481))/((0.00707946)-(0.00630957))  
  
    if (((0.00707946)<=x) and (x<=(0.00794328))): 
        return (10.7487) + (x-(0.00707946))*((10.7499)-(10.7487))/((0.00794328)-(0.00707946))  
  
    if (((0.00794328)<=x) and (x<=(0.00891251))): 
        return (10.7499) + (x-(0.00794328))*((10.7529)-(10.7499))/((0.00891251)-(0.00794328))  
  
    if (((0.00891251)<=x) and (x<=(0.01))): 
        return (10.7529) + (x-(0.00891251))*((10.7606)-(10.7529))/((0.01)-(0.00891251))  
  
    if (((0.01)<=x) and (x<=(0.0112202))): 
        return (10.7606) + (x-(0.01))*((10.7783)-(10.7606))/((0.0112202)-(0.01))  
  
    if (((0.0112202)<=x) and (x<=(0.0125892))): 
        return (10.7783) + (x-(0.0112202))*((10.8141)-(10.7783))/((0.0125892)-(0.0112202))  
  
    if (((0.0125892)<=x) and (x<=(0.0141254))): 
        return (10.8141) + (x-(0.0125892))*((10.8789)-(10.8141))/((0.0141254)-(0.0125892))  
  
    if (((0.0141254)<=x) and (x<=(0.0158489))): 
        return (10.8789) + (x-(0.0141254))*((10.9853)-(10.8789))/((0.0158489)-(0.0141254))  
  
    if (((0.0158489)<=x) and (x<=(0.0177828))): 
        return (10.9853) + (x-(0.0158489))*((11.1449)-(10.9853))/((0.0177828)-(0.0158489))  
  
    if (((0.0177828)<=x) and (x<=(0.0199526))): 
        return (11.1449) + (x-(0.0177828))*((11.3663)-(11.1449))/((0.0199526)-(0.0177828))  
  
    if (((0.0199526)<=x) and (x<=(0.0223872))): 
        return (11.3663) + (x-(0.0199526))*((11.6524)-(11.3663))/((0.0223872)-(0.0199526))  
  
    if (((0.0223872)<=x) and (x<=(0.0251189))): 
        return (11.6524) + (x-(0.0223872))*((11.9996)-(11.6524))/((0.0251189)-(0.0223872))  
  
    if (((0.0251189)<=x) and (x<=(0.0281838))): 
        return (11.9996) + (x-(0.0251189))*((12.3984)-(11.9996))/((0.0281838)-(0.0251189))  
  
    if (((0.0281838)<=x) and (x<=(0.0316228))): 
        return (12.3984) + (x-(0.0281838))*((12.8343)-(12.3984))/((0.0316228)-(0.0281838))  
  
    if (((0.0316228)<=x) and (x<=(0.0354813))): 
        return (12.8343) + (x-(0.0316228))*((13.2906)-(12.8343))/((0.0354813)-(0.0316228))  
  
    if (((0.0354813)<=x) and (x<=(0.0398107))): 
        return (13.2906) + (x-(0.0354813))*((13.7482)-(13.2906))/((0.0398107)-(0.0354813))  
  
    if (((0.0398107)<=x) and (x<=(0.0421697))): 
        return (13.7482) + (x-(0.0398107))*((13.9683)-(13.7482))/((0.0421697)-(0.0398107))  
  
    if (((0.0421697)<=x) and (x<=(0.0446684))): 
        return (13.9683) + (x-(0.0421697))*((14.1901)-(13.9683))/((0.0446684)-(0.0421697))  
  
    if (((0.0446684)<=x) and (x<=(0.0473151))): 
        return (14.1901) + (x-(0.0446684))*((14.407)-(14.1901))/((0.0473151)-(0.0446684))  
  
    if (((0.0473151)<=x) and (x<=(0.0501187))): 
        return (14.407) + (x-(0.0473151))*((14.6185)-(14.407))/((0.0501187)-(0.0473151))  
  
    if (((0.0501187)<=x) and (x<=(0.0530885))): 
        return (14.6185) + (x-(0.0501187))*((14.8242)-(14.6185))/((0.0530885)-(0.0501187))  
  
    if (((0.0530885)<=x) and (x<=(0.0562341))): 
        return (14.8242) + (x-(0.0530885))*((15.0244)-(14.8242))/((0.0562341)-(0.0530885))  
  
    if (((0.0562341)<=x) and (x<=(0.0595662))): 
        return (15.0244) + (x-(0.0562341))*((15.2196)-(15.0244))/((0.0595662)-(0.0562341))  
  
    if (((0.0595662)<=x) and (x<=(0.0630957))): 
        return (15.2196) + (x-(0.0595662))*((15.4112)-(15.2196))/((0.0630957)-(0.0595662))  
  
    if (((0.0630957)<=x) and (x<=(0.0668344))): 
        return (15.4112) + (x-(0.0630957))*((15.6011)-(15.4112))/((0.0668344)-(0.0630957))  
  
    if (((0.0668344)<=x) and (x<=(0.0707946))): 
        return (15.6011) + (x-(0.0668344))*((15.7919)-(15.6011))/((0.0707946)-(0.0668344))  
  
    if (((0.0707946)<=x) and (x<=(0.0749894))): 
        return (15.7919) + (x-(0.0707946))*((15.9872)-(15.7919))/((0.0749894)-(0.0707946))  
  
    if (((0.0749894)<=x) and (x<=(0.0794328))): 
        return (15.9872) + (x-(0.0749894))*((16.1916)-(15.9872))/((0.0794328)-(0.0749894))  
  
    if (((0.0794328)<=x) and (x<=(0.0841395))): 
        return (16.1916) + (x-(0.0794328))*((16.4111)-(16.1916))/((0.0841395)-(0.0794328))  
  
    if (((0.0841395)<=x) and (x<=(0.0891251))): 
        return (16.4111) + (x-(0.0841395))*((16.6533)-(16.4111))/((0.0891251)-(0.0841395))  
  
    if (((0.0891251)<=x) and (x<=(0.0944061))): 
        return (16.6533) + (x-(0.0891251))*((16.9276)-(16.6533))/((0.0944061)-(0.0891251))  
  
    if (((0.0944061)<=x) and (x<=(0.1))): 
        return (16.9276) + (x-(0.0944061))*((17.185)-(16.9276))/((0.1)-(0.0944061))  
  
    if (((0.1)<=x) and (x<=(0.105925))): 
        return (17.185) + (x-(0.1))*((17.7572)-(17.185))/((0.105925)-(0.1))  
  
    if (((0.105925)<=x) and (x<=(0.112202))): 
        return (17.7572) + (x-(0.105925))*((18.4474)-(17.7572))/((0.112202)-(0.105925))  
  
    if (((0.112202)<=x) and (x<=(0.11885))): 
        return (18.4474) + (x-(0.112202))*((19.3339)-(18.4474))/((0.11885)-(0.112202))  
  
    if (((0.11885)<=x) and (x<=(0.125892))): 
        return (19.3339) + (x-(0.11885))*((20.4648)-(19.3339))/((0.125892)-(0.11885))  
  
    if (((0.125892)<=x) and (x<=(0.133352))): 
        return (20.4648) + (x-(0.125892))*((21.8982)-(20.4648))/((0.133352)-(0.125892))  
  
    if (((0.133352)<=x) and (x<=(0.141254))): 
        return (21.8982) + (x-(0.133352))*((23.7052)-(21.8982))/((0.141254)-(0.133352))  
  
    if (((0.141254)<=x) and (x<=(0.149624))): 
        return (23.7052) + (x-(0.141254))*((25.972)-(23.7052))/((0.149624)-(0.141254))  
  
    if (((0.149624)<=x) and (x<=(0.158489))): 
        return (25.972) + (x-(0.149624))*((28.2245)-(25.972))/((0.158489)-(0.149624))  
  
    if (((0.158489)<=x) and (x<=(0.167881))): 
        return (28.2245) + (x-(0.158489))*((29.4206)-(28.2245))/((0.167881)-(0.158489))  
  
    if (((0.167881)<=x) and (x<=(0.177828))): 
        return (29.4206) + (x-(0.167881))*((31.6361)-(29.4206))/((0.177828)-(0.167881))  
  
    if (((0.177828)<=x) and (x<=(0.188365))): 
        return (31.6361) + (x-(0.177828))*((34.4863)-(31.6361))/((0.188365)-(0.177828))  
  
    if (((0.188365)<=x) and (x<=(0.199526))): 
        return (34.4863) + (x-(0.188365))*((37.852)-(34.4863))/((0.199526)-(0.188365))  
  
    if (((0.199526)<=x) and (x<=(0.211349))): 
        return (37.852) + (x-(0.199526))*((41.5153)-(37.852))/((0.211349)-(0.199526))  
  
    if (((0.211349)<=x) and (x<=(0.223872))): 
        return (41.5153) + (x-(0.211349))*((45.3538)-(41.5153))/((0.223872)-(0.211349))  
  
    if (((0.223872)<=x) and (x<=(0.237138))): 
        return (45.3538) + (x-(0.223872))*((48.0584)-(45.3538))/((0.237138)-(0.223872))  
  
    if (((0.237138)<=x) and (x<=(0.251189))): 
        return (48.0584) + (x-(0.237138))*((50.4746)-(48.0584))/((0.251189)-(0.237138))  
  
    if (((0.251189)<=x) and (x<=(0.266072))): 
        return (50.4746) + (x-(0.251189))*((52.6912)-(50.4746))/((0.266072)-(0.251189))  
  
    if (((0.266072)<=x) and (x<=(0.281838))): 
        return (52.6912) + (x-(0.266072))*((54.7199)-(52.6912))/((0.281838)-(0.266072))  
  
    if (((0.281838)<=x) and (x<=(0.298538))): 
        return (54.7199) + (x-(0.281838))*((56.5719)-(54.7199))/((0.298538)-(0.281838))  
  
    if (((0.298538)<=x) and (x<=(0.316228))): 
        return (56.5719) + (x-(0.298538))*((58.2587)-(56.5719))/((0.316228)-(0.298538))  
  
    if (((0.316228)<=x) and (x<=(0.334966))): 
        return (58.2587) + (x-(0.316228))*((59.7915)-(58.2587))/((0.334966)-(0.316228))  
  
    if (((0.334966)<=x) and (x<=(0.354814))): 
        return (59.7915) + (x-(0.334966))*((61.182)-(59.7915))/((0.354814)-(0.334966))  
  
    if (((0.354814)<=x) and (x<=(0.375837))): 
        return (61.182) + (x-(0.354814))*((62.4413)-(61.182))/((0.375837)-(0.354814))  
  
    if (((0.375837)<=x) and (x<=(0.398107))): 
        return (62.4413) + (x-(0.375837))*((63.5808)-(62.4413))/((0.398107)-(0.375837))  
  
    if (((0.398107)<=x) and (x<=(0.421696))): 
        return (63.5808) + (x-(0.398107))*((64.612)-(63.5808))/((0.421696)-(0.398107))  
  
    if (((0.421696)<=x) and (x<=(0.446684))): 
        return (64.612) + (x-(0.421696))*((65.5461)-(64.612))/((0.446684)-(0.421696))  
  
    if (((0.446684)<=x) and (x<=(0.473152))): 
        return (65.5461) + (x-(0.446684))*((66.3946)-(65.5461))/((0.473152)-(0.446684))  
  
    if (((0.473152)<=x) and (x<=(0.501187))): 
        return (66.3946) + (x-(0.473152))*((67.1597)-(66.3946))/((0.501187)-(0.473152))  
  
    if (((0.501187)<=x) and (x<=(0.530885))): 
        return (67.1597) + (x-(0.501187))*((67.8939)-(67.1597))/((0.530885)-(0.501187))  
  
    if (((0.530885)<=x) and (x<=(0.562341))): 
        return (67.8939) + (x-(0.530885))*((68.7759)-(67.8939))/((0.562341)-(0.530885))  
  
    if (((0.562341)<=x) and (x<=(0.595662))): 
        return (68.7759) + (x-(0.562341))*((69.6566)-(68.7759))/((0.595662)-(0.562341))  
  
    if (((0.595662)<=x) and (x<=(0.630958))): 
        return (69.6566) + (x-(0.595662))*((70.5363)-(69.6566))/((0.630958)-(0.595662))  
  
    if (((0.630958)<=x) and (x<=(0.668344))): 
        return (70.5363) + (x-(0.630958))*((71.4147)-(70.5363))/((0.668344)-(0.630958))  
  
    if (((0.668344)<=x) and (x<=(0.707946))): 
        return (71.4147) + (x-(0.668344))*((72.2922)-(71.4147))/((0.707946)-(0.668344))  
  
    if (((0.707946)<=x) and (x<=(0.749894))): 
        return (72.2922) + (x-(0.707946))*((73.1681)-(72.2922))/((0.749894)-(0.707946))  
  
    if (((0.749894)<=x) and (x<=(0.794328))): 
        return (73.1681) + (x-(0.749894))*((73.5283)-(73.1681))/((0.794328)-(0.749894))  
  
    if (((0.794328)<=x) and (x<=(0.841395))): 
        return (73.5283) + (x-(0.794328))*((73.7778)-(73.5283))/((0.841395)-(0.794328))  
  
    if (((0.841395)<=x) and (x<=(0.891251))): 
        return (73.7778) + (x-(0.841395))*((74.6022)-(73.7778))/((0.891251)-(0.841395))  
  
    if (((0.891251)<=x) and (x<=(0.944062))): 
        return (74.6022) + (x-(0.891251))*((75.4267)-(74.6022))/((0.944062)-(0.891251))  
  
    if (((0.944062)<=x) and (x<=(1))): 
        return (75.4267) + (x-(0.944062))*((76.2513)-(75.4267))/((1)-(0.944062))  
  
    if (((1)<=x) and (x<=(1.05925))): 
        return (76.2513) + (x-(1))*((77.0757)-(76.2513))/((1.05925)-(1))  
  
    if (((1.05925)<=x) and (x<=(1.12202))): 
        return (77.0757) + (x-(1.05925))*((77.9001)-(77.0757))/((1.12202)-(1.05925))  
  
    if (((1.12202)<=x) and (x<=(1.1885))): 
        return (77.9001) + (x-(1.12202))*((78.7244)-(77.9001))/((1.1885)-(1.12202))  
  
    if (((1.1885)<=x) and (x<=(1.25893))): 
        return (78.7244) + (x-(1.1885))*((78.9288)-(78.7244))/((1.25893)-(1.1885))  
  
    if (((1.25893)<=x) and (x<=(1.33352))): 
        return (78.9288) + (x-(1.25893))*((78.7639)-(78.9288))/((1.33352)-(1.25893))  
  
    if (((1.33352)<=x) and (x<=(1.41254))): 
        return (78.7639) + (x-(1.33352))*((79.3379)-(78.7639))/((1.41254)-(1.33352))  
  
    if (((1.41254)<=x) and (x<=(1.49624))): 
        return (79.3379) + (x-(1.41254))*((79.8415)-(79.3379))/((1.49624)-(1.41254))  
  
    if (((1.49624)<=x) and (x<=(1.58489))): 
        return (79.8415) + (x-(1.49624))*((80.3185)-(79.8415))/((1.58489)-(1.49624))  
  
    if (((1.58489)<=x) and (x<=(1.67881))): 
        return (80.3185) + (x-(1.58489))*((80.7923)-(80.3185))/((1.67881)-(1.58489))  
  
    if (((1.67881)<=x) and (x<=(1.77828))): 
        return (80.7923) + (x-(1.67881))*((81.2365)-(80.7923))/((1.77828)-(1.67881))  
  
    if (((1.77828)<=x) and (x<=(1.88365))): 
        return (81.2365) + (x-(1.77828))*((81.6576)-(81.2365))/((1.88365)-(1.77828))  
  
    if (((1.88365)<=x) and (x<=(1.99526))): 
        return (81.6576) + (x-(1.88365))*((82.0548)-(81.6576))/((1.99526)-(1.88365))  
  
    if (((1.99526)<=x) and (x<=(2.11349))): 
        return (82.0548) + (x-(1.99526))*((82.4277)-(82.0548))/((2.11349)-(1.99526))  
  
    if (((2.11349)<=x) and (x<=(2.23872))): 
        return (82.4277) + (x-(2.11349))*((82.7759)-(82.4277))/((2.23872)-(2.11349))  
  
    if (((2.23872)<=x) and (x<=(2.37138))): 
        return (82.7759) + (x-(2.23872))*((83.0996)-(82.7759))/((2.37138)-(2.23872))  
  
    if (((2.37138)<=x) and (x<=(2.51189))): 
        return (83.0996) + (x-(2.37138))*((83.5428)-(83.0996))/((2.51189)-(2.37138))  
  
    if (((2.51189)<=x) and (x<=(2.81838))): 
        return (83.5428) + (x-(2.51189))*((83.9617)-(83.5428))/((2.81838)-(2.51189))  
  
    if (((2.81838)<=x) and (x<=(3.16228))): 
        return (83.9617) + (x-(2.81838))*((84.4027)-(83.9617))/((3.16228)-(2.81838))  
  
    if (((3.16228)<=x) and (x<=(3.54814))): 
        return (84.4027) + (x-(3.16228))*((84.767)-(84.4027))/((3.54814)-(3.16228))  
  
    if (((3.54814)<=x) and (x<=(3.98107))): 
        return (84.767) + (x-(3.54814))*((85.0646)-(84.767))/((3.98107)-(3.54814))  
  
    if (((3.98107)<=x) and (x<=(4.46684))): 
        return (85.0646) + (x-(3.98107))*((85.3058)-(85.0646))/((4.46684)-(3.98107))  
  
    if (((4.46684)<=x) and (x<=(5.01187))): 
        return (85.3058) + (x-(4.46684))*((85.4996)-(85.3058))/((5.01187)-(4.46684))  
  
    if (((5.01187)<=x) and (x<=(5.62341))): 
        return (85.4996) + (x-(5.01187))*((85.6551)-(85.4996))/((5.62341)-(5.01187))  
  
    if (((5.62341)<=x) and (x<=(6.30958))): 
        return (85.6551) + (x-(5.62341))*((85.7808)-(85.6551))/((6.30958)-(5.62341))  
  
    if (((6.30958)<=x) and (x<=(7.07946))): 
        return (85.7808) + (x-(6.30958))*((85.886)-(85.7808))/((7.07946)-(6.30958))  
  
    if (((7.07946)<=x) and (x<=(7.94329))): 
        return (85.886) + (x-(7.07946))*((85.9834)-(85.886))/((7.94329)-(7.07946))  
  
    if (((7.94329)<=x) and (x<=(8.91251))): 
        return (85.9834) + (x-(7.94329))*((86.0916)-(85.9834))/((8.91251)-(7.94329))  
  
    if (((8.91251)<=x) and (x<=(10))): 
        return (86.0916) + (x-(8.91251))*((86.2291)-(86.0916))/((10)-(8.91251))  
  
    if (((10)<=x) and (x<=(10.5925))): 
        return (86.2291) + (x-(10))*((86.3512)-(86.2291))/((10.5925)-(10))  
  
    if (((10.5925)<=x) and (x<=(11.2202))): 
        return (86.3512) + (x-(10.5925))*((86.4774)-(86.3512))/((11.2202)-(10.5925))  
  
    if (((11.2202)<=x) and (x<=(11.885))): 
        return (86.4774) + (x-(11.2202))*((86.6326)-(86.4774))/((11.885)-(11.2202))  
  
    if (((11.885)<=x) and (x<=(12.5892))): 
        return (86.6326) + (x-(11.885))*((86.8218)-(86.6326))/((12.5892)-(11.885))  
  
    if (((12.5892)<=x) and (x<=(13.3352))): 
        return (86.8218) + (x-(12.5892))*((87.0497)-(86.8218))/((13.3352)-(12.5892))  
  
    if (((13.3352)<=x) and (x<=(14.1254))): 
        return (87.0497) + (x-(13.3352))*((87.3208)-(87.0497))/((14.1254)-(13.3352))  
  
    if (((14.1254)<=x) and (x<=(14.9624))): 
        return (87.3208) + (x-(14.1254))*((87.6381)-(87.3208))/((14.9624)-(14.1254))  
  
    if (((14.9624)<=x) and (x<=(15.8489))): 
        return (87.6381) + (x-(14.9624))*((88.0035)-(87.6381))/((15.8489)-(14.9624))  
  
    if (((15.8489)<=x) and (x<=(16.788))): 
        return (88.0035) + (x-(15.8489))*((88.4187)-(88.0035))/((16.788)-(15.8489))  
  
    if (((16.788)<=x) and (x<=(17.7828))): 
        return (88.4187) + (x-(16.788))*((88.8826)-(88.4187))/((17.7828)-(16.788))  
  
    if (((17.7828)<=x) and (x<=(18.8365))): 
        return (88.8826) + (x-(17.7828))*((89.3941)-(88.8826))/((18.8365)-(17.7828))  
  
    if (((18.8365)<=x) and (x<=(19.9526))): 
        return (89.3941) + (x-(18.8365))*((89.9497)-(89.3941))/((19.9526)-(18.8365))  
  
    if (((19.9526)<=x) and (x<=(21.1349))): 
        return (89.9497) + (x-(19.9526))*((90.5452)-(89.9497))/((21.1349)-(19.9526))  
  
    if (((21.1349)<=x) and (x<=(22.3872))): 
        return (90.5452) + (x-(21.1349))*((91.1758)-(90.5452))/((22.3872)-(21.1349))  
  
    if (((22.3872)<=x) and (x<=(23.7137))): 
        return (91.1758) + (x-(22.3872))*((91.8354)-(91.1758))/((23.7137)-(22.3872))  
  
    if (((23.7137)<=x) and (x<=(25.1189))): 
        return (91.8354) + (x-(23.7137))*((92.5174)-(91.8354))/((25.1189)-(23.7137))  
  
    if (((25.1189)<=x) and (x<=(26.6073))): 
        return (92.5174) + (x-(25.1189))*((93.2147)-(92.5174))/((26.6073)-(25.1189))  
  
    if (((26.6073)<=x) and (x<=(28.1838))): 
        return (93.2147) + (x-(26.6073))*((93.921)-(93.2147))/((28.1838)-(26.6073))  
  
    if (((28.1838)<=x) and (x<=(29.8539))): 
        return (93.921) + (x-(28.1838))*((94.6294)-(93.921))/((29.8539)-(28.1838))  
  
    if (((29.8539)<=x) and (x<=(31.6228))): 
        return (94.6294) + (x-(29.8539))*((95.3334)-(94.6294))/((31.6228)-(29.8539))  
  
    if (((31.6228)<=x) and (x<=(33.4965))): 
        return (95.3334) + (x-(31.6228))*((96.0271)-(95.3334))/((33.4965)-(31.6228))  
  
    if (((33.4965)<=x) and (x<=(35.4813))): 
        return (96.0271) + (x-(33.4965))*((96.7054)-(96.0271))/((35.4813)-(33.4965))  
  
    if (((35.4813)<=x) and (x<=(37.5837))): 
        return (96.7054) + (x-(35.4813))*((97.3639)-(96.7054))/((37.5837)-(35.4813))  
  
    if (((37.5837)<=x) and (x<=(39.8107))): 
        return (97.3639) + (x-(37.5837))*((97.9984)-(97.3639))/((39.8107)-(37.5837))  
  
    if (((39.8107)<=x) and (x<=(42.1696))): 
        return (97.9984) + (x-(39.8107))*((98.6061)-(97.9984))/((42.1696)-(39.8107))  
  
    if (((42.1696)<=x) and (x<=(44.6684))): 
        return (98.6061) + (x-(42.1696))*((99.1845)-(98.6061))/((44.6684)-(42.1696))  
  
    if (((44.6684)<=x) and (x<=(47.3151))): 
        return (99.1845) + (x-(44.6684))*((99.7317)-(99.1845))/((47.3151)-(44.6684))  
  
    if (((47.3151)<=x) and (x<=(50.1187))): 
        return (99.7317) + (x-(47.3151))*((100.247)-(99.7317))/((50.1187)-(47.3151))  
  
    if (((50.1187)<=x) and (x<=(53.0885))): 
        return (100.247) + (x-(50.1187))*((100.73)-(100.247))/((53.0885)-(50.1187))  
  
    if (((53.0885)<=x) and (x<=(56.2341))): 
        return (100.73) + (x-(53.0885))*((101.18)-(100.73))/((56.2341)-(53.0885))  
  
    if (((56.2341)<=x) and (x<=(59.5664))): 
        return (101.18) + (x-(56.2341))*((101.598)-(101.18))/((59.5664)-(56.2341))  
  
    if (((59.5664)<=x) and (x<=(63.0957))): 
        return (101.598) + (x-(59.5664))*((101.985)-(101.598))/((63.0957)-(59.5664))  
  
    if (((63.0957)<=x) and (x<=(66.8344))): 
        return (101.985) + (x-(63.0957))*((102.342)-(101.985))/((66.8344)-(63.0957))  
  
    if (((66.8344)<=x) and (x<=(70.7946))): 
        return (102.342) + (x-(66.8344))*((102.669)-(102.342))/((70.7946)-(66.8344))  
  
    if (((70.7946)<=x) and (x<=(74.9894))): 
        return (102.669) + (x-(70.7946))*((102.97)-(102.669))/((74.9894)-(70.7946))  
  
    if (((74.9894)<=x) and (x<=(79.4328))): 
        return (102.97) + (x-(74.9894))*((103.244)-(102.97))/((79.4328)-(74.9894))  
  
    if (((79.4328)<=x) and (x<=(84.1395))): 
        return (103.244) + (x-(79.4328))*((103.494)-(103.244))/((84.1395)-(79.4328))  
  
    if (((84.1395)<=x) and (x<=(89.1251))): 
        return (103.494) + (x-(84.1395))*((103.721)-(103.494))/((89.1251)-(84.1395))  
  
    if (((89.1251)<=x) and (x<=(94.4061))): 
        return (103.721) + (x-(89.1251))*((103.927)-(103.721))/((94.4061)-(89.1251))  
  
    if (((94.4061)<=x) and (x<=(100))): 
        return (103.927) + (x-(94.4061))*((104.113)-(103.927))/((100)-(94.4061))  
  
    if (((100)<=x) and (x<=(105.925))): 
        return (104.113) + (x-(100))*((104.282)-(104.113))/((105.925)-(100))  
  
    if (((105.925)<=x) and (x<=(112.202))): 
        return (104.282) + (x-(105.925))*((104.434)-(104.282))/((112.202)-(105.925))  
  
    if (((112.202)<=x) and (x<=(118.85))): 
        return (104.434) + (x-(112.202))*((104.571)-(104.434))/((118.85)-(112.202))  
  
    if (((118.85)<=x) and (x<=(125.892))): 
        return (104.571) + (x-(118.85))*((104.694)-(104.571))/((125.892)-(118.85))  
  
    if (((125.892)<=x) and (x<=(133.352))): 
        return (104.694) + (x-(125.892))*((104.805)-(104.694))/((133.352)-(125.892))  
  
    if (((133.352)<=x) and (x<=(141.254))): 
        return (104.805) + (x-(133.352))*((104.905)-(104.805))/((141.254)-(133.352))  
  
    if (((141.254)<=x) and (x<=(149.624))): 
        return (104.905) + (x-(141.254))*((104.994)-(104.905))/((149.624)-(141.254))  
  
    if (((149.624)<=x) and (x<=(158.489))): 
        return (104.994) + (x-(149.624))*((105.074)-(104.994))/((158.489)-(149.624))  
  
    if (((158.489)<=x) and (x<=(167.88))): 
        return (105.074) + (x-(158.489))*((105.146)-(105.074))/((167.88)-(158.489))  
  
    if (((167.88)<=x) and (x<=(177.828))): 
        return (105.146) + (x-(167.88))*((105.21)-(105.146))/((177.828)-(167.88))  
  
    if (((177.828)<=x) and (x<=(188.366))): 
        return (105.21) + (x-(177.828))*((105.267)-(105.21))/((188.366)-(177.828))  
  
    if (((188.366)<=x) and (x<=(199.526))): 
        return (105.267) + (x-(188.366))*((105.319)-(105.267))/((199.526)-(188.366))  
  
    if (((199.526)<=x) and (x<=(211.349))): 
        return (105.319) + (x-(199.526))*((105.365)-(105.319))/((211.349)-(199.526))  
  
    if (((211.349)<=x) and (x<=(223.873))): 
        return (105.365) + (x-(211.349))*((105.406)-(105.365))/((223.873)-(211.349))  
  
    if (((223.873)<=x) and (x<=(237.137))): 
        return (105.406) + (x-(223.873))*((105.443)-(105.406))/((237.137)-(223.873))  
  
    if (((237.137)<=x) and (x<=(251.189))): 
        return (105.443) + (x-(237.137))*((105.475)-(105.443))/((251.189)-(237.137))  
  
    if (((251.189)<=x) and (x<=(266.072))): 
        return (105.475) + (x-(251.189))*((105.505)-(105.475))/((266.072)-(251.189))  
  
    if (((266.072)<=x) and (x<=(281.838))): 
        return (105.505) + (x-(266.072))*((105.531)-(105.505))/((281.838)-(266.072))  
  
    if (((281.838)<=x) and (x<=(298.538))): 
        return (105.531) + (x-(281.838))*((105.555)-(105.531))/((298.538)-(281.838))  
  
    if (((298.538)<=x) and (x<=(316.228))): 
        return (105.555) + (x-(298.538))*((105.576)-(105.555))/((316.228)-(298.538))  
  
    if (((316.228)<=x) and (x<=(334.966))): 
        return (105.576) + (x-(316.228))*((105.594)-(105.576))/((334.966)-(316.228))  
  
    if (((334.966)<=x) and (x<=(354.813))): 
        return (105.594) + (x-(334.966))*((105.611)-(105.594))/((354.813)-(334.966))  
  
    if (((354.813)<=x) and (x<=(375.839))): 
        return (105.611) + (x-(354.813))*((105.626)-(105.611))/((375.839)-(354.813))  
  
    if (((375.839)<=x) and (x<=(398.107))): 
        return (105.626) + (x-(375.839))*((105.639)-(105.626))/((398.107)-(375.839))  
  
    if (((398.107)<=x) and (x<=(421.697))): 
        return (105.639) + (x-(398.107))*((105.651)-(105.639))/((421.697)-(398.107))  
  
    if (((421.697)<=x) and (x<=(446.685))): 
        return (105.651) + (x-(421.697))*((105.661)-(105.651))/((446.685)-(421.697))  
  
    if (((446.685)<=x) and (x<=(473.152))): 
        return (105.661) + (x-(446.685))*((105.671)-(105.661))/((473.152)-(446.685))  
  
    if (((473.152)<=x) and (x<=(501.187))): 
        return (105.671) + (x-(473.152))*((105.679)-(105.671))/((501.187)-(473.152))  
  
    if (((501.187)<=x) and (x<=(530.884))): 
        return (105.679) + (x-(501.187))*((105.687)-(105.679))/((530.884)-(501.187))  
  
    if (((530.884)<=x) and (x<=(562.341))): 
        return (105.687) + (x-(530.884))*((105.694)-(105.687))/((562.341)-(530.884))  
  
    if (((562.341)<=x) and (x<=(595.662))): 
        return (105.694) + (x-(562.341))*((105.7)-(105.694))/((595.662)-(562.341))  
  
    if (((595.662)<=x) and (x<=(630.957))): 
        return (105.7) + (x-(595.662))*((105.705)-(105.7))/((630.957)-(595.662))  
  
    if (((630.957)<=x) and (x<=(668.344))): 
        return (105.705) + (x-(630.957))*((105.71)-(105.705))/((668.344)-(630.957))  
  
    if (((668.344)<=x) and (x<=(707.946))): 
        return (105.71) + (x-(668.344))*((105.714)-(105.71))/((707.946)-(668.344))  
  
    if (((707.946)<=x) and (x<=(749.894))): 
        return (105.714) + (x-(707.946))*((105.718)-(105.714))/((749.894)-(707.946))  
  
    if (((749.894)<=x) and (x<=(794.328))): 
        return (105.718) + (x-(749.894))*((105.721)-(105.718))/((794.328)-(749.894))  
  
    if (((794.328)<=x) and (x<=(841.397))): 
        return (105.721) + (x-(794.328))*((105.724)-(105.721))/((841.397)-(794.328))  
  
    if (((841.397)<=x) and (x<=(891.253))): 
        return (105.724) + (x-(841.397))*((105.727)-(105.724))/((891.253)-(841.397))  
  
    if (((891.253)<=x) and (x<=(944.061))): 
        return (105.727) + (x-(891.253))*((105.73)-(105.727))/((944.061)-(891.253))  
  
    if (((944.061)<=x) and (x<=(1000))): 
        return (105.73) + (x-(944.061))*((105.732)-(105.73))/((1000)-(944.061))  
  
    if (((1000)<=x) and (x<=(1059.25))): 
        return (105.732) + (x-(1000))*((105.734)-(105.732))/((1059.25)-(1000))  
  
    if (((1059.25)<=x) and (x<=(1122.02))): 
        return (105.734) + (x-(1059.25))*((105.735)-(105.734))/((1122.02)-(1059.25))  
  
    if (((1122.02)<=x) and (x<=(1188.5))): 
        return (105.735) + (x-(1122.02))*((105.737)-(105.735))/((1188.5)-(1122.02))  
  
    if (((1188.5)<=x) and (x<=(1258.93))): 
        return (105.737) + (x-(1188.5))*((105.738)-(105.737))/((1258.93)-(1188.5))  
  
    if (((1258.93)<=x) and (x<=(1333.52))): 
        return (105.738) + (x-(1258.93))*((105.739)-(105.738))/((1333.52)-(1258.93))  
  
    if (((1333.52)<=x) and (x<=(1412.54))): 
        return (105.739) + (x-(1333.52))*((105.74)-(105.739))/((1412.54)-(1333.52))  
  
    if (((1412.54)<=x) and (x<=(1496.23))): 
        return (105.74) + (x-(1412.54))*((105.741)-(105.74))/((1496.23)-(1412.54))  
  
    if (((1496.23)<=x) and (x<=(1584.89))): 
        return (105.741) + (x-(1496.23))*((105.742)-(105.741))/((1584.89)-(1496.23))  
  
    if (((1584.89)<=x) and (x<=(1678.81))): 
        return (105.742) + (x-(1584.89))*((105.743)-(105.742))/((1678.81)-(1584.89))  
  
    if (((1678.81)<=x) and (x<=(1778.28))): 
        return (105.743) + (x-(1678.81))*((105.744)-(105.743))/((1778.28)-(1678.81))  
  
    if (((1778.28)<=x) and (x<=(1883.65))): 
        return (105.744) + (x-(1778.28))*((105.745)-(105.744))/((1883.65)-(1778.28))  
  
    if (((1883.65)<=x) and (x<=(1995.26))): 
        return (105.745) + (x-(1883.65))*((105.745)-(105.745))/((1995.26)-(1883.65))  
  
    if (((1995.26)<=x) and (x<=(2113.49))): 
        return (105.745) + (x-(1995.26))*((105.745)-(105.745))/((2113.49)-(1995.26))  
  
    if (((2113.49)<=x) and (x<=(2238.72))): 
        return (105.745) + (x-(2113.49))*((105.746)-(105.745))/((2238.72)-(2113.49))  
  
    if (((2238.72)<=x) and (x<=(2371.37))): 
        return (105.746) + (x-(2238.72))*((105.747)-(105.746))/((2371.37)-(2238.72))  
  
    if (((2371.37)<=x) and (x<=(2511.89))): 
        return (105.747) + (x-(2371.37))*((105.747)-(105.747))/((2511.89)-(2371.37))  
  
    if (((2511.89)<=x) and (x<=(2660.72))): 
        return (105.747) + (x-(2511.89))*((105.748)-(105.747))/((2660.72)-(2511.89))  
  
    if (((2660.72)<=x) and (x<=(2818.4))): 
        return (105.748) + (x-(2660.72))*((105.748)-(105.748))/((2818.4)-(2660.72))  
  
    if (((2818.4)<=x) and (x<=(2985.38))): 
        return (105.748) + (x-(2818.4))*((105.748)-(105.748))/((2985.38)-(2818.4))  
  
    if (((2985.38)<=x) and (x<=(3162.28))): 
        return (105.748) + (x-(2985.38))*((105.748)-(105.748))/((3162.28)-(2985.38))  
  
    if (((3162.28)<=x) and (x<=(3349.66))): 
        return (105.748) + (x-(3162.28))*((105.748)-(105.748))/((3349.66)-(3162.28))  
  
    if (((3349.66)<=x) and (x<=(3548.14))): 
        return (105.748) + (x-(3349.66))*((105.749)-(105.748))/((3548.14)-(3349.66))  
  
    if (((3548.14)<=x) and (x<=(3758.38))): 
        return (105.749) + (x-(3548.14))*((105.749)-(105.749))/((3758.38)-(3548.14))  
  
    if (((3758.38)<=x) and (x<=(3981.07))): 
        return (105.749) + (x-(3758.38))*((105.749)-(105.749))/((3981.07)-(3758.38))  
  
    if (((3981.07)<=x) and (x<=(4216.97))): 
        return (105.749) + (x-(3981.07))*((105.749)-(105.749))/((4216.97)-(3981.07))  
  
    if (((4216.97)<=x) and (x<=(4466.84))): 
        return (105.749) + (x-(4216.97))*((105.749)-(105.749))/((4466.84)-(4216.97))  
  
    if (((4466.84)<=x) and (x<=(4731.51))): 
        return (105.749) + (x-(4466.84))*((105.749)-(105.749))/((4731.51)-(4466.84))  
  
    if (((4731.51)<=x) and (x<=(5011.87))): 
        return (105.749) + (x-(4731.51))*((105.749)-(105.749))/((5011.87)-(4731.51))  
  
    if (((5011.87)<=x) and (x<=(5308.84))): 
        return (105.749) + (x-(5011.87))*((105.749)-(105.749))/((5308.84)-(5011.87))  
  
    if (((5308.84)<=x) and (x<=(5623.43))): 
        return (105.749) + (x-(5308.84))*((105.75)-(105.749))/((5623.43)-(5308.84))  
  
    if (((5623.43)<=x) and (x<=(5956.64))): 
        return (105.75) + (x-(5623.43))*((105.75)-(105.75))/((5956.64)-(5623.43))  
  
    if (((5956.64)<=x) and (x<=(6309.59))): 
        return (105.75) + (x-(5956.64))*((105.749)-(105.75))/((6309.59)-(5956.64))  
  
    if (((6309.59)<=x) and (x<=(6683.45))): 
        return (105.749) + (x-(6309.59))*((105.75)-(105.749))/((6683.45)-(6309.59))  
  
    if (((6683.45)<=x) and (x<=(7079.46))): 
        return (105.75) + (x-(6683.45))*((105.75)-(105.75))/((7079.46)-(6683.45))  
  
    if (((7079.46)<=x) and (x<=(7498.94))): 
        return (105.75) + (x-(7079.46))*((105.75)-(105.75))/((7498.94)-(7079.46))  
  
    if (((7498.94)<=x) and (x<=(7943.28))): 
        return (105.75) + (x-(7498.94))*((105.75)-(105.75))/((7943.28)-(7498.94))  
  
    if (((7943.28)<=x) and (x<=(8413.95))): 
        return (105.75) + (x-(7943.28))*((105.749)-(105.75))/((8413.95)-(7943.28))  
  
    if (((8413.95)<=x) and (x<=(8912.53))): 
        return (105.749) + (x-(8413.95))*((105.75)-(105.749))/((8912.53)-(8413.95))  
  
    if (((8912.53)<=x) and (x<=(9440.61))): 
        return (105.75) + (x-(8912.53))*((105.75)-(105.75))/((9440.61)-(8912.53))  
  
    if (((9440.61)<=x) and (x<=(10000))): 
        return (105.75) + (x-(9440.61))*((105.749)-(105.75))/((10000)-(9440.61))  
  
    if (((10000)<=x) and (x<=(10592.6))): 
        return (105.749) + (x-(10000))*((105.75)-(105.749))/((10592.6)-(10000))  
  
    if (((10592.6)<=x) and (x<=(11220.2))): 
        return (105.75) + (x-(10592.6))*((105.75)-(105.75))/((11220.2)-(10592.6))  
  
    if (((11220.2)<=x) and (x<=(11885))): 
        return (105.75) + (x-(11220.2))*((105.75)-(105.75))/((11885)-(11220.2))  
  
    if (((11885)<=x) and (x<=(12589.2))): 
        return (105.75) + (x-(11885))*((105.749)-(105.75))/((12589.2)-(11885))   
    else:
        return 105.75

# %% [markdown]
# #Coupled Equations

# %% [markdown]
# ## Parameters

# %%
#All in GeV

GF = 1.17e-5  # Fermi constant
MW = 80.38    # Mass of W boson
MP = 2.43e18  # Planck Mass

# %% [markdown]
# ## Functions

# %% [markdown]
# Here we have the definition for the following equations:
#
# **Reheating Temperatura:**
#
# $T_{RH} = \left(\frac{90}{\pi^2 \kappa^{2}} \right)^{1/4} \sqrt{\Gamma M_{pl}}$ ,
#
# where $\kappa = \frac{5}{2}$ to ensure continuity  of the Hubble rate among different periods(arXiv:2003.01723).
#
# **Temperature as a function of entropy:**
#
# $T \left( A, S \right) = \left( \frac{45}{2 \pi} \right)^{1/3} S^{1/3} \frac{T_{RH}}{A}$  ,
#
# where $A = a \times T_{RH}$, where $a$ is the scale factor.
#
# **Decay Rate:**
#
# $\Gamma = \frac{G_F^2}{48\pi^3} M_{S_2}^5\frac{M_W^4}{M_{W^\prime}^4}$
#
# **Number density:**
#
# $n = \frac{g}{2 \pi^2} m^2 T K_ 2 \left( \frac{m}{T} \right)$
#
# **Entropy density:**
#
# $s \left( A, S \right) = \frac{ 2 \pi^2}{45} \left(T\left( A, S \right) \right)^3$
#
# **Thermally averaged cross section:**
#
# $\langle \sigma v \rangle = \frac{134 G_f^2}{27 \zeta(3)^2 \pi } \frac{M_W^4}{M_{mediator}^4} T(A,S)^2$

# %%
def sci_notation(number, sig_fig=2):
  ret_string = "{0:.{1:d}e}".format(number, sig_fig)
  a,b = ret_string.split("e")
  b = int(b) #removed leading "+" and strips leading zeros too.
  return a + " \\times 10^" + '{'+ str(b) + '}'

def Tr(): #Reheat Temperature
  return (90/(np.pi**2*(5/2)**2))**(1/4)*np.sqrt(Gamma()*MP)

def T(A,S):
  return (2*np.pi/45)**(-1/3)*S**(1/3)*Tr()/A

def Gamma(): # Width decay S2
    return GF**2.*MW**4./(48.*np.pi**3.)*M**5.*(1/Mb**4.)

def H(A,R,y2_,S):
    return 1/(np.sqrt(3)*MP)*(Tr()**2/A**2)*np.sqrt(R + A*S*mS2*y2_/Tr())

def nSeq_mp(A,S,mS):
    return 2./(2.*np.pi**2.)*mS**2.*fmul(T(A,S),besselk(2,fdiv(mS,T(A,S))))

def nSeq_(A,S,mS):
    return 2./(2.*np.pi**2.)*mS**2.*T(A,S)*kv(2,mS/T(A,S))

def s(A,S):
    return 2.*np.pi**2./45.*(T(A,S))**3.  

def H_(T):
    return np.pi/(np.sqrt(90)*MP)*(T)**2

def svSSLL(A,S):
    return ((134*GF**2*MW**4)/(27*sp.special.zeta(3)**2*np.pi*Mb**4))*((T(A,S))**2)

def PHI(y2,A,S):
  result = list(np.zeros((len(y2))))
  for i in range(len(y2)):
    result[i] = y2[i]*A[i]*S[i]*mS2/Tr()
  return result


def log_(number):
    return math.log(number, 10)

# %% [markdown]
# ## Coupled Equations

# %% [markdown]
# $\frac{dS}{dA} \ = \frac{m_{S_2} \Gamma S Y_{S_2}}{T H A} $
#
# $\frac{d R}{dA}   = S \frac{m_{S_2} Y_{S_2} \Gamma}{T_{RH} H}$
#
# $ \frac{d Y_{S_1}}{dA} = \frac{A^2}{S}  \frac{R_{S_1}}{H T_r^3} - \frac{Y_{S_1}}{S} \frac{dS}{dA}$
#
# $\frac{d Y_{S_2}}{dA} = \frac{A^2}{S}  \frac{R_{S_2}}{H T_r^3} - \frac{Y_{S_2}}{S} \frac{dS}{dA}$

# %%
def Coupled_Equations(yy, A):
    S = yy[0]
    R = yy[1]
    y1 = yy[2]
    y2 = yy[3]

    ds =  mS2*Gamma()*S*y2/T(A,S)/H(A,R,y2,S)/A

    dR = S*mS2*y2*Gamma()/Tr()/H(A,R,y2,S)
    
    dy1 = 1/S/Tr()**3/H(A,R,y2,S)*\
    (- Tr()**6*S**2/A/A/A/A * svSSLL(A,S) * (y1**2 - (nSeq_mp(A,S,mS1)/s(A,S))**2 ) 
          + S*Tr()**3/A *besselk(1,mS2/T(A,S))/besselk(2,mS2/T(A,S))*Gamma()
          *(y2 - y1* nSeq_mp(A,S,mS2)/nSeq_mp(A,S,mS1))) - y1/S *ds 
    
    dy2 =  1/S/Tr()**3/H(A,R,y2,S)*\
    (- Tr()**6*S**2/A/A/A/A * svSSLL(A,S) * (y2**2 - (nSeq_mp(A,S,mS2)/s(A,S))**2 ) 
          - S*Tr()**3/A * (besselk(1,mS2/T(A,S))/besselk(2,mS2/T(A,S))*Gamma()
          *(y2 - y1* nSeq_mp(A,S,mS2)/nSeq_mp(A,S,mS1)) )) - y2/S *ds 
    
    return ds, dR, dy1, dy2

# %% [markdown]
# Initial Conditions

# %%
mS1=2.2e-6
mS2= 60.0e0
Mb= 4.7e6
M=mS2
Tr()
# Out:
# 0.0042377728210117325

# %%
#Initial Conditions#
S_i = 897.
R_i = 1790
AA = np.logspace(-8,8,1000)
A_i = AA[0]
y10 = nSeq_(A_i,S_i,mS1)/s(A_i,S_i)
y20 = nSeq_(A_i,S_i,mS2)/s(A_i,S_i)

yy0 = [S_i, R_i,y10,y20]
yy0
# Out:
# [897.0, 1790, 0.46196920146079506, 0.46196920145409587]

# %%
start = time.time()
#Odeint Solve#
mp.dps = 50


sol = odeint(Coupled_Equations,yy0, AA )
S = sol[:,0]
R = sol[:,1]
y1 = sol[:,2]
y2 = sol[:,3]

end = time.time()
print(end - start)
# Out:
# 40.808228492736816

# %% [markdown]
# ## Graph Coupled Equations

# %%
####################################################
plt.figure(dpi = 100)
plt.rcParams["font.family"] = "serif"
plt.rcParams["font.weight"] = "bold"
plt.rcParams["font.size"] = "15"
plt.rcParams["mathtext.fontset"] = "dejavuserif"
####################################################

def Temperature(S,A):
  value = np.zeros([len(A)])
  for i in range(len(A)):
    value[i] =  T(A[i],S[i])
  return value
  
T_ = np.logspace(-8,8,1000)

TT = Temperature(S,AA)

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20, 8), dpi =100)
#Fist plot#
anchored_text_1 = AnchoredText(r"$m_{S_1} = $" +"${MS1:.1f}$".format(MS1 = mS1*1.0e6 ) +  "$ \ KeV $" + '\n'\
                               r"$m_{S_2} = $" +"${MS2:2.1f}$".format(MS2 = mS2 ) +  "$ \ GeV $" + '\n'\
                               r"$m_{W^\prime} = %s \ GeV$" %(sci_notation(Mb, 1)), loc=3)

anchored_text_2 = AnchoredText(r"$T_r = {Tr:.2f} \ MeV$".format(Tr = sym.sympify(Tr())*1.0e3) + '\n'\
                              r"$\Delta = %s $" %(sci_notation(S[999]/ S[0], 1)), loc=2)


axes[0].axhline(y= 4.5e-10/mS1, color = '0.6', ls = '--', lw = 3, alpha = 0.5) 
#axes[0].loglog(mS2/TT, y1_,color = '0.6',ls = '-.',lw=5)
axes[0].loglog(mS2/TT, y1,'g',lw=5,label=r'$Y_{S_1}$')
axes[0].loglog(mS2/TT, y2,'c',lw=5,label=r'$Y_{S_2}$')


axes[0].legend(loc=1,fontsize=15)
axes[0].set_ylim(1.0e-7,1.0e1)
axes[0].set_xlim(1.0e-1,1e9)


axes[0].add_artist(anchored_text_1)
axes[0].set_xlabel(xlabel = '$m_{S_2}/T $', fontsize= 20)
axes[0].text(1.5e-1,4.25e-10/mS1, '$\Omega h^2 = 0.12$', horizontalalignment='left',alpha = 0.7 ,verticalalignment='bottom', fontweight='bold', fontsize= 18, color = '0.6')
axes[0].text(1.3e4,4.0e-5, '$Y_{S_1}$ without non-thermal contribution', horizontalalignment='left',alpha = 1 ,\
             verticalalignment='bottom', fontweight='bold', fontsize= 11.5, color = '0.6')
####################################################################################################################################
#Second plot#
axes[1].loglog(mS2/TT, S,'r-',lw=5,label=r'$S$')
axes[1].loglog(mS2/TT,R,'k',lw=5,label=r'$R = \rho_R \times a^4$')
Phi_field = PHI(y2,AA,S)
axes[1].loglog(mS2/TT, Phi_field,'b-',lw=5,label=r'$\Phi_{S_2} = \frac{Y_{S_2} \ S \ m_{S_2} A}{T_r}$')
axes[1].set_xlabel(xlabel = '$m_{S_2}/T $', fontsize= 20)
axes[1].set_ylim(1.0e1,1.0e11)
axes[1].set_xlim(3.0e-1,1e8)
axes[1].text(6.0e6,1.0e9, '$\\rho_R \\times a^4 $', horizontalalignment='left' ,verticalalignment='bottom', fontweight='bold', fontsize= 16, color = 'black')
axes[1].text(2.0e7,5.0e6, '$S $', horizontalalignment='left',verticalalignment='bottom', fontweight='bold', fontsize= 16, color = 'red')
axes[1].text(2.0e0,3.0e4, '$\\rho_{S_2} \\times a^4 $',rotation = 37,horizontalalignment='left' ,verticalalignment='bottom', fontweight='bold', fontsize= 16, color = 'blue')
axes[1].text(1.5e5,5.0e4, '$\Delta \simeq \\frac{S_r}{S_i} $', horizontalalignment='left',alpha = 0.8 ,verticalalignment='bottom', fontweight='bold', fontsize= 24, color = 'gray')
axes[1].annotate(
    '', xy=(1.0e5, S[999]), xycoords='data',
    xytext=(1.0e5, S[0]), textcoords='data',
    arrowprops= dict(arrowstyle= '<|-|>', lw = 3, color = 'gray', alpha = 0.8))

axes[1].add_artist(anchored_text_2)

plt.show()

# %% [markdown]
# # Numerical Abundance

# %%
def Numerical_Abundance(MS1, MS2_Start, MS2_End, Interval, Mmediator_Start, Mmediator_End, precision):
  MS2 = np.logspace(MS2_Start,MS2_End,Interval) #
  data = np.zeros((len(MS2),2))
  mS1 = MS1
  for i in range(len(MS2)):
    mS2= MS2[i]
    if i == 0:
      Mb_ = np.logspace(Mmediator_Start,Mmediator_End,100)
    else:
      Mb_ = np.logspace(log_(data[i-1][1]),12,100) 
    for j in range(len(Mb_)):
      Mb = Mb_[j]
      M = mS2
      S_i = 897.
      R_i = 1790.
      AA = np.logspace(-6,6,25)
      A_i = AA[0]
      y10 = nSeq_(A_i,S_i,mS1)/s(A_i,S_i)
      y20 = nSeq_(A_i,S_i,mS2)/s(A_i,S_i)
      yy0 = [S_i, R_i,y10,y20]
      sol = odeint(Coupled_Equations,yy0, AA)
      y1 = sol[:,2]
      abundance_value = 4.5e-10/mS1
      y1_temp = y1[len(AA)-1]
      relativo = abs(y1_temp - abundance_value)/ abundance_value
      print(relativo)
      print(j, Mb, mS2)
      
      if relativo <= precision:
        data[i][0] = mS2
        data[i][1] = Mb
        print(i)
        print(relativo)
        display(Math('MS2 = %g' %mS2))
        display(Math('MW = %g' %Mb))
        display(Math('Fraction = %g' %relativo))
        break
      else:
        continue
  return data

# %%
start = time.time()
Numerical_Abundance(MS1 = 2.2e-6 , MS2_Start = 0 , MS2_End = 10, Interval = 10, Mmediator_Start = 4, Mmediator_End = 12,
                    precision = 0.2)
end = time.time()
print(end - start)
# Out:
# 0.023839215917478895
# 0 10000.0 1.0
# 0
# 0.023839215917478895
# $$MS2 = 1$$
# $$MW = 10000$$
# $$Fraction = 0.0238392$$
# 0.02383921587176767
# 0 10000.0 12.91549665014884
# 1
# 0.02383921587176767
# $$MS2 = 12.9155$$
# $$MW = 10000$$
# $$Fraction = 0.0238392$$
# 0.023839215869897637
# 0 10000.0 166.81005372000593
# 2
# 0.023839215869897637
# $$MS2 = 166.81$$
# $$MW = 10000$$
# $$Fraction = 0.0238392$$
# 0.023839126243859924
# 0 10000.0 2154.4346900318847
# 3
# 0.023839126243859924
# $$MS2 = 2154.43$$
# $$MW = 10000$$
# $$Fraction = 0.0238391$$
# 0.023839265379393893
# 0 10000.0 27825.59402207126
# 4
# 0.023839265379393893
# $$MS2 = 27825.6$$
# $$MW = 10000$$
# $$Fraction = 0.0238393$$
# 0.023839264523752523
# 0 10000.0 359381.36638046254
# 5
# 0.023839264523752523
# $$MS2 = 359381$$
# $$MW = 10000$$
# $$Fraction = 0.0238393$$
# 0.023839264741681472
# 0 10000.0 4641588.833612782
# 6
# 0.023839264741681472
# $$MS2 = 4.64159e+06$$
# $$MW = 10000$$
# $$Fraction = 0.0238393$$
# ...

# %%
MS2_ = [1,2.78256,7.74264, 21.5443, 59.9484,166.81,464.159, 1291.55, 3593.81 ,10000, 20691.4, 42813.3, 88586.7 , 183298 , 379269 , 784760 , 1.62378e+06,3.35982e+06, 6.95193e+06, 1.43845e+07 ]

Mb_l = [225702, 488895, 1.01846e+06,2.35016e+06, 5.15516e+06,1.07823e+07,2.15655e+07, 4.60995e+07, 1.03301e+08, 2.16869e+08 , 3.82651e+08 ,  6.67456e+08, 1.11933e+09 , 1.93832e+09
         , 3.41998e+09 , 5.73065e+09 ,  1.01693e+10 , 1.69318e+10, 2.89267e+10, 5.12835e+10]

# %% [markdown]
# #Bonds

# %%
##############################
####### INTRODUCTION #########
##############################

plt.figure( figsize = (8,5), dpi = 100)
plt.rcParams["font.family"] = "serif"
#plt.rcParams["font.weight"] = "ultralight"
plt.rcParams["font.size"] = "12"
plt.rcParams["mathtext.fontset"] = "dejavuserif"

################################
###### Initial Condition #######
################################
MS2 = np.logspace(-2,10, 100)
M = 60
Mb = 6.7e6
M = MS2
MS1 = 0


################################
######### Functions ############
################################



def Z_n0n_thermal(MS1,MS2):
  return np.sqrt(3.7e16*MS1*MS2**(3/2))

def Z_thermal(MS1,MS2):
  Mb = 0.55*(1/MS1*(MS2)**(3/2))**(1/2)
  mS2 = MS2
  T = Tr()
  return 0.55*(1/MS1*ge(T)**(-1/4)*(MS2)**(3/2))**(1/2)

### Abundance ###
def correct_abu(MS1,MS2):
  Mb = (2.2e16*MS1*(MS2)**(3/2))**(1/2)
  mS2 = MS2
  T = Tr()
  return (2.2e16*MS1*(MS2)**(3/2))**(1/2)

### Delta N effective ###
def DeltaN(MS2):

  return (1/0.1*4/7*(11/4)**(4/3)/3*(gs(1.0e-6)**4/gs(4.0e-3))**(1/3)/Gamma_Total*GF**2/48/np.pi**3*MW**4)**(1/4)*MS2**(5/4)

### Reheating Temperature ###
def Tr_graph(MS2):
  return 2.9e4*np.sqrt(MS2**(5/2)) 

################################
########### Graph ##############
################################

### Correct Abundance ###
MS1 = 2.0e-6
plt.loglog(MS2,correct_abu(MS1,MS2), '-',color = 'red',lw = 2 ,label = '$m_{S_1} = 2.0 \ \mathrm{KeV}$')
MS1 = 10.0e-6
plt.loglog(MS2,correct_abu(MS1,MS2), '-.',color = 'red',lw = 2 ,label = '$m_{S_1} = 10.0 \ \mathrm{KeV}$')
MS1 = 1.0e-3
plt.loglog(MS2,correct_abu(MS1,MS2), '--',color = 'red',lw = 2 ,label = '$m_{S_1} = 1.0 \ \mathrm{MeV}$')

###Plotting for Tr > 4MeV ###
#plt.loglog(MS2, Tr_graph_new(MS2), '--' ,color = 'orchid', alpha = 0.5, lw = 3)
plt.loglog(MS2, Tr_graph(MS2), color = 'orchid', alpha = 0.4, lw = 3)
plt.fill_between(MS2,Tr_graph(MS2),10**13, facecolor='orchid', alpha=0.3)
plt.text(1.0e1, 10**10, r'$ T_{RH} < 4 \ MeV $', fontsize=15, color = 'orchid', alpha = 1, rotation = 0, weight = 'light')

### Relativistic Decoupling ###
plt.loglog(MS2,9.6e3*((MS2)*(100)**(-1/6))**(3/4), color = 'green', alpha = 0.4, lw = 2)
plt.fill_between(MS2,9.6e3*((MS2)*(100)**(-1/6))**(3/4), facecolor='green', alpha=0.3)
plt.text(5.0e4, 3.0e6, '$ m_{S_2} \\gg T_f $', fontsize=15, color = 'green', alpha = 1, rotation = 23)
plt.text(1.0e4, 2.0e5, '(Non-relativistic Decoupling)', fontsize=9, color = 'green', alpha = 1, rotation = 23)

### Bound Mediator Mass ###
plt.fill_between(MS2,3.0e3,0, facecolor='blue', alpha=0.2)
plt.axhline(y= 3.0e3, color = 'blue', ls = '-', lw = 3, alpha = 0.4) 
plt.text(1.0e3, 5.0e2, 'LHC Excluded', fontsize=14, color = 'blue', alpha = 1, rotation = 0)


'''
MS2_ = [1,2.78256,7.74264, 21.5443, 59.9484,166.81,464.159, 1291.55, 3593.81 ,10000, 20691.4, 42813.3, 88586.7 , 183298 , 379269 , 784760 , 1.62378e+06,3.35982e+06, 6.95193e+06, 1.43845e+07 ]

Mb_l = [225702, 488895, 1.01846e+06,2.35016e+06, 5.15516e+06,1.07823e+07,2.15655e+07, 4.60995e+07, 1.03301e+08, 2.16869e+08 , 3.82651e+08 ,  6.67456e+08, 1.11933e+09 , 1.93832e+09
         , 3.41998e+09 , 5.73065e+09 ,  1.01693e+10 , 1.69318e+10, 2.89267e+10, 5.12835e+10]
plt.loglog(MS2_,Mb_l, 'ro', alpha = 1, lw = 2)
'''
################################
########### Layout #############
################################

plt.ylabel('$m_{W^{\prime}} \ [GeV]$', fontsize = 15, weight = 'ultralight')
plt.xlabel('$m_{S_2} \ [GeV]$', fontsize = 15, weight = 'ultralight')
plt.loglog()
plt.margins(x=0, y = 0)
#ax2.margins(x=0, y = 0)
plt.legend(shadow = True, loc = 4)
plt.ylim(1.0e2,1.0e13)
plt.xlim(1.0e-1,1.0e10)
plt.grid(alpha = 0.2, color = 'w')

plt.show()
